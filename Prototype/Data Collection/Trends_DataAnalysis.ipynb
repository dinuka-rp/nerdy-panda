# %% [markdown]
# <a href="https://colab.research.google.com/github/dinuka-rp/nerdy-panda/blob/main/Prototype/Data%20Collection/Trends_DataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trends Data Fetcher
# Functions under this colab notebook will be mostly handled by Trends Data Fetcher of the tiered high-level diagram.

# %%
# !pip install pymongo
# !pip install dnspython
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (4.1.1)
# Collecting dnspython
#   Downloading dnspython-2.2.1-py3-none-any.whl (269 kB)
#      |████████████████████████████████| 269 kB 33.3 MB/s
# Installing collected packages: dnspython
# Successfully installed dnspython-2.2.1

# %%
# Connect to MongoDB

import pymongo
from datetime import datetime

mongo_client = pymongo.MongoClient("mongodb+srv://admin:2KRv1funPDgawFu7@recsyscluster.lvxb6.mongodb.net")
mydb = mongo_client["nft-recsys"]
trends_collection = mydb["trends"]

# mydict = { "name": "John", "address": "Highway 37",
#   "created_datetime": datetime.today().replace(microsecond=0)
#  }
# x = trends_collection.insert_one(mydict)

# %% [markdown]
# # Fetch Twitter Trends data from Twitter API

# %% [markdown]
# ## twitter auth token

# %%
auth_token = ""

# %% [markdown]
# ## data fetcher

# %%
twitter_woeid = 44418

# %%
import pprint   # well-formatted print output

pp = pprint.PrettyPrinter(indent=1)

# %%
import requests

def fetch_twitter_trends(woeid=1):

  url = "https://api.twitter.com/1.1/trends/place.json?id=" + str(woeid)

  payload={}
  headers = {
    'Authorization': 'Bearer ' + auth_token,
    'Cookie': 'guest_id=v1%3A164302265238123185; guest_id_ads=v1%3A164302265238123185; guest_id_marketing=v1%3A164302265238123185; personalization_id="v1_7SOW+P3aER3WzxCMuCXiWw=="'
  }

  response = requests.request("GET", url, headers=headers, data=payload)

  if response.status_code != 200:
    print('error')

  trends = response.json()[0]['trends']
  # print(trends)
  return trends

# twitter_trends = fetch_twitter_trends()
twitter_trends = fetch_twitter_trends(woeid=twitter_woeid)

print("count",len(twitter_trends))
# print(twitter_trends)
pp.pprint(twitter_trends)
# Out:
# count 48
# [{'name': 'Fabianski',
#   'promoted_content': None,
#   'query': 'Fabianski',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Fabianski'},
#  {'name': 'Farmaajo',
#   'promoted_content': None,
#   'query': 'Farmaajo',
#   'tweet_volume': 10539,
#   'url': 'http://twitter.com/search?q=Farmaajo'},
#  {'name': 'Toffees',
#   'promoted_content': None,
#   'query': 'Toffees',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Toffees'},
#  {'name': '#MN16',
#   'promoted_content': None,
#   'query': '%23MN16',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%23MN16'},
#  {'name': '#LEEBHA',
#   'promoted_content': None,
#   'query': '%23LEEBHA',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%23LEEBHA'},
#  {'name': 'Anthony Gordon',
#   'promoted_content': None,
#   'query': '%22Anthony+Gordon%22',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%22Anthony+Gordon%22'},
#  {'name': '#WHUFC',
#   'promoted_content': None,
#   'query': '%23WHUFC',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%23WHUFC'},
#  {'name': 'Coufal',
#   'promoted_content': None,
#   'query': 'Coufal',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Coufal'},
#  {'name': 'Mavs',
#   'promoted_content': None,
#   'query': 'Mavs',
#   'tweet_volume': 21160,
#   'url': 'http://twitter.com/search?q=Mavs'},
#  {'name': 'Rodrigo',
#   'promoted_content': None,
#   'query': 'Rodrigo',
#   'tweet_volume': 55507,
#   'url': 'http://twitter.com/search?q=Rodrigo'},
#  {'name': 'Wilf',
#   'promoted_content': None,
#   'query': 'Wilf',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Wilf'},
#  {'name': 'Erin Cuthbert',
#   'promoted_content': None,
#   'query': '%22Erin+Cuthbert%22',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%22Erin+Cuthbert%22'},
#  {'name': 'Edgeley Park',
#   'promoted_content': None,
#   'query': '%22Edgeley+Park%22',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%22Edgeley+Park%22'},
#  {'name': 'Fernandinho',
#   'promoted_content': None,
#   'query': 'Fernandinho',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Fernandinho'},
#  {'name': '#sundayvibes',
#   'promoted_content': None,
#   'query': '%23sundayvibes',
#   'tweet_volume': 32773,
#   'url': 'http://twitter.com/search?q=%23sundayvibes'},
#  {'name': 'Zinchenko',
#   'promoted_content': None,
#   'query': 'Zinchenko',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Zinchenko'},
#  {'name': 'Pascal',
#   'promoted_content': None,
#   'query': 'Pascal',
#   'tweet_volume': 12210,
#   'url': 'http://twitter.com/search?q=Pascal'},
#  {'name': 'Manchester City',
#   'promoted_content': None,
#   'query': '%22Manchester+City%22',
#   'tweet_volume': 51899,
#   'url': 'http://twitter.com/search?q=%22Manchester+City%22'},
#  {'name': 'Buffalo',
#   'promoted_content': None,
#   'query': 'Buffalo',
#   'tweet_volume': 1399845,
#   'url': 'http://twitter.com/search?q=Buffalo'},
#  {'name': 'Everton',
#   'promoted_content': None,
#   'query': 'Everton',
#   'tweet_volume': 67535,
#   'url': 'http://twitter.com/search?q=Everton'},
#  {'name': 'Donna',
#   'promoted_content': None,
#   'query': 'Donna',
#   'tweet_volume': 20731,
#   'url': 'http://twitter.com/search?q=Donna'},
#  {'name': 'Rondon',
#   'promoted_content': None,
#   'query': 'Rondon',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Rondon'},
#  {'name': 'David Tennant',
#   'promoted_content': None,
#   'query': '%22David+Tennant%22',
#   'tweet_volume': 12486,
#   'url': 'http://twitter.com/search?q=%22David+Tennant%22'},
#  {'name': 'Richarlison',
#   'promoted_content': None,
#   'query': 'Richarlison',
#   'tweet_volume': 10234,
#   'url': 'http://twitter.com/search?q=Richarlison'},
#  {'name': 'Theo Hernandez',
#   'promoted_content': None,
#   'query': '%22Theo+Hernandez%22',
#   'tweet_volume': 24484,
#   'url': 'http://twitter.com/search?q=%22Theo+Hernandez%22'},
#  {'name': 'Palace',
#   'promoted_content': None,
#   'query': 'Palace',
#   'tweet_volume': 40956,
#   'url': 'http://twitter.com/search?q=Palace'},
#  {'name': 'West Ham',
#   'promoted_content': None,
#   'query': '%22West+Ham%22',
#   'tweet_volume': 106406,
#   'url': 'http://twitter.com/search?q=%22West+Ham%22'},
#  {'name': 'Mahrez',
#   'promoted_content': None,
#   'query': 'Mahrez',
#   'tweet_volume': 39196,
#   'url': 'http://twitter.com/search?q=Mahrez'},
#  {'name': 'Branthwaite',
#   'promoted_content': None,
#   'query': 'Branthwaite',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Branthwaite'},
#  {'name': 'Michael Oliver',
#   'promoted_content': None,
#   'query': '%22Michael+Oliver%22',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%22Michael+Oliver%22'},
#  {'name': 'Gomes',
#   'promoted_content': None,
#   'query': 'Gomes',
#   'tweet_volume': 20164,
#   'url': 'http://twitter.com/search?q=Gomes'},
#  {'name': 'Eriksen',
#   'promoted_content': None,
#   'query': 'Eriksen',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Eriksen'},
#  {'name': 'Burnley',
#   'promoted_content': None,
#   'query': 'Burnley',
#   'tweet_volume': 46682,
#   'url': 'http://twitter.com/search?q=Burnley'},
#  {'name': 'Angel Delight',
#   'promoted_content': None,
#   'query': '%22Angel+Delight%22',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%22Angel+Delight%22'},
#  {'name': 'Trifle',
#   'promoted_content': None,
#   'query': 'Trifle',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Trifle'},
#  {'name': 'Doucoure',
#   'promoted_content': None,
#   'query': 'Doucoure',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Doucoure'},
#  {'name': 'Rico Henry',
#   'promoted_content': None,
#   'query': '%22Rico+Henry%22',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%22Rico+Henry%22'},
#  {'name': 'Southampton',
#   'promoted_content': None,
#   'query': 'Southampton',
#   'tweet_volume': 12966,
#   'url': 'http://twitter.com/search?q=Southampton'},
#  {'name': 'Stockport',
#   'promoted_content': None,
#   'query': 'Stockport',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Stockport'},
#  {'name': 'Bowen',
#   'promoted_content': None,
#   'query': 'Bowen',
#   'tweet_volume': 38016,
#   'url': 'http://twitter.com/search?q=Bowen'},
#  {'name': 'Arctic Roll',
#   'promoted_content': None,
#   'query': '%22Arctic+Roll%22',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%22Arctic+Roll%22'},
#  {'name': 'Frank Lampard',
#   'promoted_content': None,
#   'query': '%22Frank+Lampard%22',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%22Frank+Lampard%22'},
#  {'name': 'Joffy',
#   'promoted_content': None,
#   'query': 'Joffy',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Joffy'},
#  {'name': 'Grantham',
#   'promoted_content': None,
#   'query': 'Grantham',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Grantham'},
#  {'name': 'Goodison',
#   'promoted_content': None,
#   'query': 'Goodison',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Goodison'},
#  {'name': 'Wrexham',
#   'promoted_content': None,
#   'query': 'Wrexham',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Wrexham'},
#  {'name': 'Toney',
#   'promoted_content': None,
#   'query': 'Toney',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Toney'},
#  {'name': 'Gerrard',
#   'promoted_content': None,
#   'query': 'Gerrard',
#   'tweet_volume': 28803,
#   'url': 'http://twitter.com/search?q=Gerrard'}]

# %%
# 28th Feb 2021 - around 1pm
# trends that will work with cryptokitties dataset (Zendaya) 

# this works!! zendaya, euphoria give recommendations from collected-nft-assets

# [{'name': '#โหนกระเเส', 'url': 'http://twitter.com/search?q=%23%E0%B9%82%E0%B8%AB%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B9%80%E0%B8%AA', 'promoted_content': None, 'query': '%23%E0%B9%82%E0%B8%AB%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B9%80%E0%B8%AA', 'tweet_volume': 2166180}, {'name': '#Euphoria', 'url': 'http://twitter.com/search?q=%23Euphoria', 'promoted_content': None, 'query': '%23Euphoria', 'tweet_volume': 1005172}, {'name': 'Cassie', 'url': 'http://twitter.com/search?q=Cassie', 'promoted_content': None, 'query': 'Cassie', 'tweet_volume': 416023}, {'name': 'Maddy', 'url': 'http://twitter.com/search?q=Maddy', 'promoted_content': None, 'query': 'Maddy', 'tweet_volume': 352427}, {'name': '#28Şubat', 'url': 'http://twitter.com/search?q=%2328%C5%9Eubat', 'promoted_content': None, 'query': '%2328%C5%9Eubat', 'tweet_volume': 42633}, {'name': 'Elliot', 'url': 'http://twitter.com/search?q=Elliot', 'promoted_content': None, 'query': 'Elliot', 'tweet_volume': 231872}, {'name': 'Andalucía', 'url': 'http://twitter.com/search?q=Andaluc%C3%ADa', 'promoted_content': None, 'query': 'Andaluc%C3%ADa', 'tweet_volume': 39283}, {'name': '#MondayMotivation', 'url': 'http://twitter.com/search?q=%23MondayMotivation', 'promoted_content': None, 'query': '%23MondayMotivation', 'tweet_volume': 23904}, {'name': 'Lexi', 'url': 'http://twitter.com/search?q=Lexi', 'promoted_content': None, 'query': 'Lexi', 'tweet_volume': 246787}, {'name': '#Callin_MV_Out', 'url': 'http://twitter.com/search?q=%23Callin_MV_Out', 'promoted_content': None, 'query': '%23Callin_MV_Out', 'tweet_volume': 23107}, {'name': 'Lakers', 'url': 'http://twitter.com/search?q=Lakers', 'promoted_content': None, 'query': 'Lakers', 'tweet_volume': 89051}, {'name': 'Larissa', 'url': 'http://twitter.com/search?q=Larissa', 'promoted_content': None, 'query': 'Larissa', 'tweet_volume': 329769}, {'name': 'Jules', 'url': 'http://twitter.com/search?q=Jules', 'promoted_content': None, 'query': 'Jules', 'tweet_volume': 100974}, {'name': 'sam levinson', 'url': 'http://twitter.com/search?q=%22sam+levinson%22', 'promoted_content': None, 'query': '%22sam+levinson%22', 'tweet_volume': 93293}, {'name': 'Faye', 'url': 'http://twitter.com/search?q=Faye', 'promoted_content': None, 'query': 'Faye', 'tweet_volume': 107648}, {'name': 'Nate', 'url': 'http://twitter.com/search?q=Nate', 'promoted_content': None, 'query': 'Nate', 'tweet_volume': 137511}, {'name': 'Toz Taneleri', 'url': 'http://twitter.com/search?q=%22Toz+Taneleri%22', 'promoted_content': None, 'query': '%22Toz+Taneleri%22', 'tweet_volume': None}, {'name': "NU'EST", 'url': 'http://twitter.com/search?q=NU%27EST', 'promoted_content': None, 'query': 'NU%27EST', 'tweet_volume': 13042}, {'name': '政策金利', 'url': 'http://twitter.com/search?q=%E6%94%BF%E7%AD%96%E9%87%91%E5%88%A9', 'promoted_content': None, 'query': '%E6%94%BF%E7%AD%96%E9%87%91%E5%88%A9', 'tweet_volume': None}, {'name': '非核三原則', 'url': 'http://twitter.com/search?q=%E9%9D%9E%E6%A0%B8%E4%B8%89%E5%8E%9F%E5%89%87', 'promoted_content': None, 'query': '%E9%9D%9E%E6%A0%B8%E4%B8%89%E5%8E%9F%E5%89%87', 'tweet_volume': None}, {'name': 'やまとん先生', 'url': 'http://twitter.com/search?q=%E3%82%84%E3%81%BE%E3%81%A8%E3%82%93%E5%85%88%E7%94%9F', 'promoted_content': None, 'query': '%E3%82%84%E3%81%BE%E3%81%A8%E3%82%93%E5%85%88%E7%94%9F', 'tweet_volume': None}, {'name': 'Zendaya', 'url': 'http://twitter.com/search?q=Zendaya', 'promoted_content': None, 'query': 'Zendaya', 'tweet_volume': 158640}, {'name': 'Maddie', 'url': 'http://twitter.com/search?q=Maddie', 'promoted_content': None, 'query': 'Maddie', 'tweet_volume': 38518}, {'name': 'Ashtray', 'url': 'http://twitter.com/search?q=Ashtray', 'promoted_content': None, 'query': 'Ashtray', 'tweet_volume': None}, {'name': 'Tansu Çiller', 'url': 'http://twitter.com/search?q=%22Tansu+%C3%87iller%22', 'promoted_content': None, 'query': '%22Tansu+%C3%87iller%22', 'tweet_volume': None}, {'name': '立憲・末松義規議員', 'url': 'http://twitter.com/search?q=%E7%AB%8B%E6%86%B2%E3%83%BB%E6%9C%AB%E6%9D%BE%E7%BE%A9%E8%A6%8F%E8%AD%B0%E5%93%A1', 'promoted_content': None, 'query': '%E7%AB%8B%E6%86%B2%E3%83%BB%E6%9C%AB%E6%9D%BE%E7%BE%A9%E8%A6%8F%E8%AD%B0%E5%93%A1', 'tweet_volume': None}, {'name': 'ランファ', 'url': 'http://twitter.com/search?q=%E3%83%A9%E3%83%B3%E3%83%95%E3%82%A1', 'promoted_content': None, 'query': '%E3%83%A9%E3%83%B3%E3%83%95%E3%82%A1', 'tweet_volume': 31601}, {'name': '뉴이스트', 'url': 'http://twitter.com/search?q=%EB%89%B4%EC%9D%B4%EC%8A%A4%ED%8A%B8', 'promoted_content': None, 'query': '%EB%89%B4%EC%9D%B4%EC%8A%A4%ED%8A%B8', 'tweet_volume': 17313}, {'name': 'Tiziano Ferro', 'url': 'http://twitter.com/search?q=%22Tiziano+Ferro%22', 'promoted_content': None, 'query': '%22Tiziano+Ferro%22', 'tweet_volume': None}, {'name': 'ファイナルミキサー', 'url': 'http://twitter.com/search?q=%E3%83%95%E3%82%A1%E3%82%A4%E3%83%8A%E3%83%AB%E3%83%9F%E3%82%AD%E3%82%B5%E3%83%BC', 'promoted_content': None, 'query': '%E3%83%95%E3%82%A1%E3%82%A4%E3%83%8A%E3%83%AB%E3%83%9F%E3%82%AD%E3%82%B5%E3%83%BC', 'tweet_volume': None}, {'name': 'jisoo', 'url': 'http://twitter.com/search?q=jisoo', 'promoted_content': None, 'query': 'jisoo', 'tweet_volume': 340519}, {'name': 'Lina', 'url': 'http://twitter.com/search?q=Lina', 'promoted_content': None, 'query': 'Lina', 'tweet_volume': 107987}, {'name': 'Pledis', 'url': 'http://twitter.com/search?q=Pledis', 'promoted_content': None, 'query': 'Pledis', 'tweet_volume': 108854}, {'name': 'dominic fike', 'url': 'http://twitter.com/search?q=%22dominic+fike%22', 'promoted_content': None, 'query': '%22dominic+fike%22', 'tweet_volume': 15835}, {'name': 'ロシア大幅利上げ', 'url': 'http://twitter.com/search?q=%E3%83%AD%E3%82%B7%E3%82%A2%E5%A4%A7%E5%B9%85%E5%88%A9%E4%B8%8A%E3%81%92', 'promoted_content': None, 'query': '%E3%83%AD%E3%82%B7%E3%82%A2%E5%A4%A7%E5%B9%85%E5%88%A9%E4%B8%8A%E3%81%92', 'tweet_volume': None}, {'name': '異例の声明', 'url': 'http://twitter.com/search?q=%E7%95%B0%E4%BE%8B%E3%81%AE%E5%A3%B0%E6%98%8E', 'promoted_content': None, 'query': '%E7%95%B0%E4%BE%8B%E3%81%AE%E5%A3%B0%E6%98%8E', 'tweet_volume': None}, {'name': '日本の追加制裁', 'url': 'http://twitter.com/search?q=%E6%97%A5%E6%9C%AC%E3%81%AE%E8%BF%BD%E5%8A%A0%E5%88%B6%E8%A3%81', 'promoted_content': None, 'query': '%E6%97%A5%E6%9C%AC%E3%81%AE%E8%BF%BD%E5%8A%A0%E5%88%B6%E8%A3%81', 'tweet_volume': None}, {'name': 'minhyun', 'url': 'http://twitter.com/search?q=minhyun', 'promoted_content': None, 'query': 'minhyun', 'tweet_volume': None}, {'name': '通貨防衛', 'url': 'http://twitter.com/search?q=%E9%80%9A%E8%B2%A8%E9%98%B2%E8%A1%9B', 'promoted_content': None, 'query': '%E9%80%9A%E8%B2%A8%E9%98%B2%E8%A1%9B', 'tweet_volume': None}, {'name': '米ホワイトハウス', 'url': 'http://twitter.com/search?q=%E7%B1%B3%E3%83%9B%E3%83%AF%E3%82%A4%E3%83%88%E3%83%8F%E3%82%A6%E3%82%B9', 'promoted_content': None, 'query': '%E7%B1%B3%E3%83%9B%E3%83%AF%E3%82%A4%E3%83%88%E3%83%8F%E3%82%A6%E3%82%B9', 'tweet_volume': None}, {'name': 'ルーブル', 'url': 'http://twitter.com/search?q=%E3%83%AB%E3%83%BC%E3%83%96%E3%83%AB', 'promoted_content': None, 'query': '%E3%83%AB%E3%83%BC%E3%83%96%E3%83%AB', 'tweet_volume': 29897}, {'name': 'Laurie', 'url': 'http://twitter.com/search?q=Laurie', 'promoted_content': None, 'query': 'Laurie', 'tweet_volume': 45052}, {'name': 'Sadi Somuncuoğlu', 'url': 'http://twitter.com/search?q=%22Sadi+Somuncuo%C4%9Flu%22', 'promoted_content': None, 'query': '%22Sadi+Somuncuo%C4%9Flu%22', 'tweet_volume': None}, {'name': 'Wochenstart', 'url': 'http://twitter.com/search?q=Wochenstart', 'promoted_content': None, 'query': 'Wochenstart', 'tweet_volume': None}, {'name': 'HANGGANG SA MULI ALEIAN', 'url': 'http://twitter.com/search?q=%22HANGGANG+SA+MULI+ALEIAN%22', 'promoted_content': None, 'query': '%22HANGGANG+SA+MULI+ALEIAN%22', 'tweet_volume': 18804}, {'name': '中田翔選手', 'url': 'http://twitter.com/search?q=%E4%B8%AD%E7%94%B0%E7%BF%94%E9%81%B8%E6%89%8B', 'promoted_content': None, 'query': '%E4%B8%AD%E7%94%B0%E7%BF%94%E9%81%B8%E6%89%8B', 'tweet_volume': None}, {'name': 'ロシア中銀', 'url': 'http://twitter.com/search?q=%E3%83%AD%E3%82%B7%E3%82%A2%E4%B8%AD%E9%8A%80', 'promoted_content': None, 'query': '%E3%83%AD%E3%82%B7%E3%82%A2%E4%B8%AD%E9%8A%80', 'tweet_volume': None}, {'name': 'BENJI KUMUSERYE EP3', 'url': 'http://twitter.com/search?q=%22BENJI+KUMUSERYE+EP3%22', 'promoted_content': None, 'query': '%22BENJI+KUMUSERYE+EP3%22', 'tweet_volume': None}, {'name': 'Viny', 'url': 'http://twitter.com/search?q=Viny', 'promoted_content': None, 'query': 'Viny', 'tweet_volume': 25361}, {'name': 'Baekho', 'url': 'http://twitter.com/search?q=Baekho', 'promoted_content': None, 'query': 'Baekho', 'tweet_volume': 12652}]

# 13/Mar/2022 - 2AM
# [{'name': 'Ronaldo', 'url': 'http://twitter.com/search?q=Ronaldo', 'promoted_content': None, 'query': 'Ronaldo', 'tweet_volume': 714522}, {'name': 'Maguire', 'url': 'http://twitter.com/search?q=Maguire', 'promoted_content': None, 'query': 'Maguire', 'tweet_volume': 157809}, {'name': '#MUNTOT', 'url': 'http://twitter.com/search?q=%23MUNTOT', 'promoted_content': None, 'query': '%23MUNTOT', 'tweet_volume': 209811}, {'name': '#CR7𓃵', 'url': 'http://twitter.com/search?q=%23CR7%F0%93%83%B5', 'promoted_content': None, 'query': '%23CR7%F0%93%83%B5', 'tweet_volume': 50826}, {'name': 'Pogba', 'url': 'http://twitter.com/search?q=Pogba', 'promoted_content': None, 'query': 'Pogba', 'tweet_volume': 47340}, {'name': '#MUFC', 'url': 'http://twitter.com/search?q=%23MUFC', 'promoted_content': None, 'query': '%23MUFC', 'tweet_volume': 187744}, {'name': 'Spurs', 'url': 'http://twitter.com/search?q=Spurs', 'promoted_content': None, 'query': 'Spurs', 'tweet_volume': 132987}, {'name': 'Browns', 'url': 'http://twitter.com/search?q=Browns', 'promoted_content': None, 'query': 'Browns', 'tweet_volume': 47885}, {'name': 'Sancho', 'url': 'http://twitter.com/search?q=Sancho', 'promoted_content': None, 'query': 'Sancho', 'tweet_volume': 46210}, {'name': 'Tottenham', 'url': 'http://twitter.com/search?q=Tottenham', 'promoted_content': None, 'query': 'Tottenham', 'tweet_volume': 160537}, {'name': 'Amari Cooper', 'url': 'http://twitter.com/search?q=%22Amari+Cooper%22', 'promoted_content': None, 'query': '%22Amari+Cooper%22', 'tweet_volume': 38774}, {'name': '#ENGvIRE', 'url': 'http://twitter.com/search?q=%23ENGvIRE', 'promoted_content': None, 'query': '%23ENGvIRE', 'tweet_volume': 16816}, {'name': 'GOAT', 'url': 'http://twitter.com/search?q=GOAT', 'promoted_content': None, 'query': 'GOAT', 'tweet_volume': 169233}, {'name': '#melfest', 'url': 'http://twitter.com/search?q=%23melfest', 'promoted_content': None, 'query': '%23melfest', 'tweet_volume': 12851}, {'name': 'Cowboys', 'url': 'http://twitter.com/search?q=Cowboys', 'promoted_content': None, 'query': 'Cowboys', 'tweet_volume': 45403}, {'name': 'رونالدو', 'url': 'http://twitter.com/search?q=%D8%B1%D9%88%D9%86%D8%A7%D9%84%D8%AF%D9%88', 'promoted_content': None, 'query': '%D8%B1%D9%88%D9%86%D8%A7%D9%84%D8%AF%D9%88', 'tweet_volume': 39695}, {'name': 'Rashford', 'url': 'http://twitter.com/search?q=Rashford', 'promoted_content': None, 'query': 'Rashford', 'tweet_volume': 41258}, {'name': 'Romero', 'url': 'http://twitter.com/search?q=Romero', 'promoted_content': None, 'query': 'Romero', 'tweet_volume': 30256}, {'name': 'Baker', 'url': 'http://twitter.com/search?q=Baker', 'promoted_content': None, 'query': 'Baker', 'tweet_volume': 31689}, {'name': 'Bohannon', 'url': 'http://twitter.com/search?q=Bohannon', 'promoted_content': None, 'query': 'Bohannon', 'tweet_volume': None}, {'name': 'Iowa', 'url': 'http://twitter.com/search?q=Iowa', 'promoted_content': None, 'query': 'Iowa', 'tweet_volume': 30507}, {'name': 'Telles', 'url': 'http://twitter.com/search?q=Telles', 'promoted_content': None, 'query': 'Telles', 'tweet_volume': 13115}, {'name': 'Traci', 'url': 'http://twitter.com/search?q=Traci', 'promoted_content': None, 'query': 'Traci', 'tweet_volume': 72009}, {'name': 'Old Trafford', 'url': 'http://twitter.com/search?q=%22Old+Trafford%22', 'promoted_content': None, 'query': '%22Old+Trafford%22', 'tweet_volume': 40693}, {'name': 'Matic', 'url': 'http://twitter.com/search?q=Matic', 'promoted_content': None, 'query': 'Matic', 'tweet_volume': 144277}, {'name': 'TURMA DA GKAY NO MION', 'url': 'http://twitter.com/search?q=%22TURMA+DA+GKAY+NO+MION%22', 'promoted_content': None, 'query': '%22TURMA+DA+GKAY+NO+MION%22', 'tweet_volume': None}, {'name': 'Will Wade', 'url': 'http://twitter.com/search?q=%22Will+Wade%22', 'promoted_content': None, 'query': '%22Will+Wade%22', 'tweet_volume': None}, {'name': 'Tom Brady', 'url': 'http://twitter.com/search?q=%22Tom+Brady%22', 'promoted_content': None, 'query': '%22Tom+Brady%22', 'tweet_volume': 11898}, {'name': 'Cleveland', 'url': 'http://twitter.com/search?q=Cleveland', 'promoted_content': None, 'query': 'Cleveland', 'tweet_volume': 24828}, {'name': 'Kane', 'url': 'http://twitter.com/search?q=Kane', 'promoted_content': None, 'query': 'Kane', 'tweet_volume': 57987}, {'name': 'Landry', 'url': 'http://twitter.com/search?q=Landry', 'promoted_content': None, 'query': 'Landry', 'tweet_volume': None}, {'name': 'Hat-trick', 'url': 'http://twitter.com/search?q=Hat-trick', 'promoted_content': None, 'query': 'Hat-trick', 'tweet_volume': 75079}, {'name': 'Dier', 'url': 'http://twitter.com/search?q=Dier', 'promoted_content': None, 'query': 'Dier', 'tweet_volume': None}, {'name': 'Cornelia', 'url': 'http://twitter.com/search?q=Cornelia', 'promoted_content': None, 'query': 'Cornelia', 'tweet_volume': None}, {'name': 'Texas A&M', 'url': 'http://twitter.com/search?q=%22Texas+A%26M%22', 'promoted_content': None, 'query': '%22Texas+A%26M%22', 'tweet_volume': None}, {'name': 'Ororo', 'url': 'http://twitter.com/search?q=Ororo', 'promoted_content': None, 'query': 'Ororo', 'tweet_volume': 10068}, {'name': 'Campaz', 'url': 'http://twitter.com/search?q=Campaz', 'promoted_content': None, 'query': 'Campaz', 'tweet_volume': None}, {'name': 'Bentancur', 'url': 'http://twitter.com/search?q=Bentancur', 'promoted_content': None, 'query': 'Bentancur', 'tweet_volume': None}, {'name': 'Gallup', 'url': 'http://twitter.com/search?q=Gallup', 'promoted_content': None, 'query': 'Gallup', 'tweet_volume': None}, {'name': 'كريستيانو', 'url': 'http://twitter.com/search?q=%D9%83%D8%B1%D9%8A%D8%B3%D8%AA%D9%8A%D8%A7%D9%86%D9%88', 'promoted_content': None, 'query': '%D9%83%D8%B1%D9%8A%D8%B3%D8%AA%D9%8A%D8%A7%D9%86%D9%88', 'tweet_volume': 19663}, {'name': 'Keegan Murray', 'url': 'http://twitter.com/search?q=%22Keegan+Murray%22', 'promoted_content': None, 'query': '%22Keegan+Murray%22', 'tweet_volume': None}, {'name': 'Thuli P', 'url': 'http://twitter.com/search?q=%22Thuli+P%22', 'promoted_content': None, 'query': '%22Thuli+P%22', 'tweet_volume': None}, {'name': 'Lloris', 'url': 'http://twitter.com/search?q=Lloris', 'promoted_content': None, 'query': 'Lloris', 'tweet_volume': None}, {'name': 'El Bicho', 'url': 'http://twitter.com/search?q=%22El+Bicho%22', 'promoted_content': None, 'query': '%22El+Bicho%22', 'tweet_volume': 13613}, {'name': '#الاهلي_الطايي', 'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A_%D8%A7%D9%84%D8%B7%D8%A7%D9%8A%D9%8A', 'promoted_content': None, 'query': '%23%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A_%D8%A7%D9%84%D8%B7%D8%A7%D9%8A%D9%8A', 'tweet_volume': 46852}, {'name': '#İstanbulkar', 'url': 'http://twitter.com/search?q=%23%C4%B0stanbulkar', 'promoted_content': None, 'query': '%23%C4%B0stanbulkar', 'tweet_volume': None}, {'name': '#GönülDağı', 'url': 'http://twitter.com/search?q=%23G%C3%B6n%C3%BClDa%C4%9F%C4%B1', 'promoted_content': None, 'query': '%23G%C3%B6n%C3%BClDa%C4%9F%C4%B1', 'tweet_volume': None}, {'name': '#ManUtd', 'url': 'http://twitter.com/search?q=%23ManUtd', 'promoted_content': None, 'query': '%23ManUtd', 'tweet_volume': None}, {'name': '#imamoğluistifa', 'url': 'http://twitter.com/search?q=%23imamo%C4%9Fluistifa', 'promoted_content': None, 'query': '%23imamo%C4%9Fluistifa', 'tweet_volume': None}, {'name': '#GGMU', 'url': 'http://twitter.com/search?q=%23GGMU', 'promoted_content': None, 'query': '%23GGMU', 'tweet_volume': None}]

# %% [markdown]
# test adding fields to dictionary

# %%
twitter_trends[0]['random_field'] = "random_string"

print(twitter_trends[0])
# Out:
# {'name': 'WE ARE BULLETPROOF', 'url': 'http://twitter.com/search?q=%22WE+ARE+BULLETPROOF%22', 'promoted_content': None, 'query': '%22WE+ARE+BULLETPROOF%22', 'tweet_volume': 371806, 'random_field': 'random_string'}

# %% [markdown]
# ## Analyze received data from the trends API

# %%
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# print(f"{bcolors.WARNING}Warning: No active frommets remain. Continue?{bcolors.ENDC}")
# print(bcolors.WARNING + "Warning: No active frommets remain. Continue?" + bcolors.ENDC)

# %%
for trend in twitter_trends:
  if trend['tweet_volume'] == None:
    print(f"{bcolors.WARNING}{trend}{bcolors.ENDC}")
  else:
    # print(f"{bcolors.OKGREEN}{trend}{bcolors.ENDC}")
      print(trend)
# Out:
# {'name': '#14MartTıpBayramı', 'url': 'http://twitter.com/search?q=%2314MartT%C4%B1pBayram%C4%B1', 'promoted_content': None, 'query': '%2314MartT%C4%B1pBayram%C4%B1', 'tweet_volume': 69073}
# {'name': 'Viny', 'url': 'http://twitter.com/search?q=Viny', 'promoted_content': None, 'query': 'Viny', 'tweet_volume': 168776}
# {'name': 'ホワイトデー', 'url': 'http://twitter.com/search?q=%E3%83%9B%E3%83%AF%E3%82%A4%E3%83%88%E3%83%87%E3%83%BC', 'promoted_content': None, 'query': '%E3%83%9B%E3%83%AF%E3%82%A4%E3%83%88%E3%83%87%E3%83%BC', 'tweet_volume': 695516}
# {'name': 'Scooby', 'url': 'http://twitter.com/search?q=Scooby', 'promoted_content': None, 'query': 'Scooby', 'tweet_volume': 252751}
# {'name': '#MondayMotivation', 'url': 'http://twitter.com/search?q=%23MondayMotivation', 'promoted_content': None, 'query': '%23MondayMotivation', 'tweet_volume': 48091}
# {'name': 'Gustavo', 'url': 'http://twitter.com/search?q=Gustavo', 'promoted_content': None, 'query': 'Gustavo', 'tweet_volume': 217378}
# {'name': 'Lucas', 'url': 'http://twitter.com/search?q=Lucas', 'promoted_content': None, 'query': 'Lucas', 'tweet_volume': 300243}
# {'name': '#Pazartesi', 'url': 'http://twitter.com/search?q=%23Pazartesi', 'promoted_content': None, 'query': '%23Pazartesi', 'tweet_volume': None}
# {'name': '東京ミュウミュウ', 'url': 'http://twitter.com/search?q=%E6%9D%B1%E4%BA%AC%E3%83%9F%E3%83%A5%E3%82%A6%E3%83%9F%E3%83%A5%E3%82%A6', 'promoted_content': None, 'query': '%E6%9D%B1%E4%BA%AC%E3%83%9F%E3%83%A5%E3%82%A6%E3%83%9F%E3%83%A5%E3%82%A6', 'tweet_volume': 40474}
# {'name': '#mondaythoughts', 'url': 'http://twitter.com/search?q=%23mondaythoughts', 'promoted_content': None, 'query': '%23mondaythoughts', 'tweet_volume': None}
# {'name': 'e-Tax', 'url': 'http://twitter.com/search?q=e-Tax', 'promoted_content': None, 'query': 'e-Tax', 'tweet_volume': None}
# {'name': '#11MillionWinInMyHeart', 'url': 'http://twitter.com/search?q=%2311MillionWinInMyHeart', 'promoted_content': None, 'query': '%2311MillionWinInMyHeart', 'tweet_volume': 182034}
# {'name': 'Chaewon', 'url': 'http://twitter.com/search?q=Chaewon', 'promoted_content': None, 'query': 'Chaewon', 'tweet_volume': 46427}
# {'name': '화이트데이', 'url': 'http://twitter.com/search?q=%ED%99%94%EC%9D%B4%ED%8A%B8%EB%8D%B0%EC%9D%B4', 'promoted_content': None, 'query': '%ED%99%94%EC%9D%B4%ED%8A%B8%EB%8D%B0%EC%9D%B4', 'tweet_volume': 366203}
# {'name': '67 X', 'url': 'http://twitter.com/search?q=%2267+X%22', 'promoted_content': None, 'query': '%2267+X%22', 'tweet_volume': None}
# {'name': 'いーあるふぁんくらぶ', 'url': 'http://twitter.com/search?q=%E3%81%84%E3%83%BC%E3%81%82%E3%82%8B%E3%81%B5%E3%81%81%E3%82%93%E3%81%8F%E3%82%89%E3%81%B6', 'promoted_content': None, 'query': '%E3%81%84%E3%83%BC%E3%81%82%E3%82%8B%E3%81%B5%E3%81%81%E3%82%93%E3%81%8F%E3%82%89%E3%81%B6', 'tweet_volume': 34296}
# {'name': '確定申告の締め切り', 'url': 'http://twitter.com/search?q=%E7%A2%BA%E5%AE%9A%E7%94%B3%E5%91%8A%E3%81%AE%E7%B7%A0%E3%82%81%E5%88%87%E3%82%8A', 'promoted_content': None, 'query': '%E7%A2%BA%E5%AE%9A%E7%94%B3%E5%91%8A%E3%81%AE%E7%B7%A0%E3%82%81%E5%88%87%E3%82%8A', 'tweet_volume': None}
# {'name': 'Tom Brady', 'url': 'http://twitter.com/search?q=%22Tom+Brady%22', 'promoted_content': None, 'query': '%22Tom+Brady%22', 'tweet_volume': 371438}
# {'name': 'くも膜下出血', 'url': 'http://twitter.com/search?q=%E3%81%8F%E3%82%82%E8%86%9C%E4%B8%8B%E5%87%BA%E8%A1%80', 'promoted_content': None, 'query': '%E3%81%8F%E3%82%82%E8%86%9C%E4%B8%8B%E5%87%BA%E8%A1%80', 'tweet_volume': 24926}
# {'name': 'RGガオガイガー', 'url': 'http://twitter.com/search?q=RG%E3%82%AC%E3%82%AA%E3%82%AC%E3%82%A4%E3%82%AC%E3%83%BC', 'promoted_content': None, 'query': 'RG%E3%82%AC%E3%82%AA%E3%82%AC%E3%82%A4%E3%82%AC%E3%83%BC', 'tweet_volume': 14219}
# {'name': 'Love Around Win', 'url': 'http://twitter.com/search?q=%22Love+Around+Win%22', 'promoted_content': None, 'query': '%22Love+Around+Win%22', 'tweet_volume': 162168}
# {'name': 'スーパードールリカちゃん', 'url': 'http://twitter.com/search?q=%E3%82%B9%E3%83%BC%E3%83%91%E3%83%BC%E3%83%89%E3%83%BC%E3%83%AB%E3%83%AA%E3%82%AB%E3%81%A1%E3%82%83%E3%82%93', 'promoted_content': None, 'query': '%E3%82%B9%E3%83%BC%E3%83%91%E3%83%BC%E3%83%89%E3%83%BC%E3%83%AB%E3%83%AA%E3%82%AB%E3%81%A1%E3%82%83%E3%82%93', 'tweet_volume': 12817}
# {'name': 'NR限定戦', 'url': 'http://twitter.com/search?q=NR%E9%99%90%E5%AE%9A%E6%88%A6', 'promoted_content': None, 'query': 'NR%E9%99%90%E5%AE%9A%E6%88%A6', 'tweet_volume': None}
# {'name': 'Donaldson', 'url': 'http://twitter.com/search?q=Donaldson', 'promoted_content': None, 'query': 'Donaldson', 'tweet_volume': 29826}
# {'name': 'アドえもん', 'url': 'http://twitter.com/search?q=%E3%82%A2%E3%83%89%E3%81%88%E3%82%82%E3%82%93', 'promoted_content': None, 'query': '%E3%82%A2%E3%83%89%E3%81%88%E3%82%82%E3%82%93', 'tweet_volume': None}
# {'name': 'マリク・イシュタール', 'url': 'http://twitter.com/search?q=%E3%83%9E%E3%83%AA%E3%82%AF%E3%83%BB%E3%82%A4%E3%82%B7%E3%83%A5%E3%82%BF%E3%83%BC%E3%83%AB', 'promoted_content': None, 'query': '%E3%83%9E%E3%83%AA%E3%82%AF%E3%83%BB%E3%82%A4%E3%82%B7%E3%83%A5%E3%82%BF%E3%83%BC%E3%83%AB', 'tweet_volume': None}
# {'name': 'O DG', 'url': 'http://twitter.com/search?q=%22O+DG%22', 'promoted_content': None, 'query': '%22O+DG%22', 'tweet_volume': 83748}
# {'name': 'Wochenstart', 'url': 'http://twitter.com/search?q=Wochenstart', 'promoted_content': None, 'query': 'Wochenstart', 'tweet_volume': None}
# {'name': 'バレンタイン', 'url': 'http://twitter.com/search?q=%E3%83%90%E3%83%AC%E3%83%B3%E3%82%BF%E3%82%A4%E3%83%B3', 'promoted_content': None, 'query': '%E3%83%90%E3%83%AC%E3%83%B3%E3%82%BF%E3%82%A4%E3%83%B3', 'tweet_volume': 98710}
# {'name': 'トリプルA面', 'url': 'http://twitter.com/search?q=%E3%83%88%E3%83%AA%E3%83%97%E3%83%ABA%E9%9D%A2', 'promoted_content': None, 'query': '%E3%83%88%E3%83%AA%E3%83%97%E3%83%ABA%E9%9D%A2', 'tweet_volume': None}
# {'name': '征海美亜さん', 'url': 'http://twitter.com/search?q=%E5%BE%81%E6%B5%B7%E7%BE%8E%E4%BA%9C%E3%81%95%E3%82%93', 'promoted_content': None, 'query': '%E5%BE%81%E6%B5%B7%E7%BE%8E%E4%BA%9C%E3%81%95%E3%82%93', 'tweet_volume': 19574}
# {'name': '一転起訴', 'url': 'http://twitter.com/search?q=%E4%B8%80%E8%BB%A2%E8%B5%B7%E8%A8%B4', 'promoted_content': None, 'query': '%E4%B8%80%E8%BB%A2%E8%B5%B7%E8%A8%B4', 'tweet_volume': None}
# {'name': 'NRフェス', 'url': 'http://twitter.com/search?q=NR%E3%83%95%E3%82%A7%E3%82%B9', 'promoted_content': None, 'query': 'NR%E3%83%95%E3%82%A7%E3%82%B9', 'tweet_volume': None}
# {'name': 'Start in die Woche', 'url': 'http://twitter.com/search?q=%22Start+in+die+Woche%22', 'promoted_content': None, 'query': '%22Start+in+die+Woche%22', 'tweet_volume': None}
# {'name': 'KIM JISOO', 'url': 'http://twitter.com/search?q=%22KIM+JISOO%22', 'promoted_content': None, 'query': '%22KIM+JISOO%22', 'tweet_volume': 15989}
# {'name': 'JISOO IN MAPLE WORLD', 'url': 'http://twitter.com/search?q=%22JISOO+IN+MAPLE+WORLD%22', 'promoted_content': None, 'query': '%22JISOO+IN+MAPLE+WORLD%22', 'tweet_volume': 15192}
# {'name': 'Sakura', 'url': 'http://twitter.com/search?q=Sakura', 'promoted_content': None, 'query': 'Sakura', 'tweet_volume': 140756}
# {'name': 'Petro', 'url': 'http://twitter.com/search?q=Petro', 'promoted_content': None, 'query': 'Petro', 'tweet_volume': 277161}
# {'name': 'Menhan Kerja Fokus', 'url': 'http://twitter.com/search?q=%22Menhan+Kerja+Fokus%22', 'promoted_content': None, 'query': '%22Menhan+Kerja+Fokus%22', 'tweet_volume': None}
# {'name': 'Diplomasi Pertahanan Prabowo', 'url': 'http://twitter.com/search?q=%22Diplomasi+Pertahanan+Prabowo%22', 'promoted_content': None, 'query': '%22Diplomasi+Pertahanan+Prabowo%22', 'tweet_volume': None}
# {'name': 'ガッシュ2', 'url': 'http://twitter.com/search?q=%E3%82%AC%E3%83%83%E3%82%B7%E3%83%A52', 'promoted_content': None, 'query': '%E3%82%AC%E3%83%83%E3%82%B7%E3%83%A52', 'tweet_volume': 62686}
# {'name': '河井夫妻', 'url': 'http://twitter.com/search?q=%E6%B2%B3%E4%BA%95%E5%A4%AB%E5%A6%BB', 'promoted_content': None, 'query': '%E6%B2%B3%E4%BA%95%E5%A4%AB%E5%A6%BB', 'tweet_volume': None}
# {'name': 'Indonesia Tangguh Disegani', 'url': 'http://twitter.com/search?q=%22Indonesia+Tangguh+Disegani%22', 'promoted_content': None, 'query': '%22Indonesia+Tangguh+Disegani%22', 'tweet_volume': None}
# {'name': 'JISOOxDIOR FOR VOGUE KOREA', 'url': 'http://twitter.com/search?q=%22JISOOxDIOR+FOR+VOGUE+KOREA%22', 'promoted_content': None, 'query': '%22JISOOxDIOR+FOR+VOGUE+KOREA%22', 'tweet_volume': None}
# {'name': '確定申告締め', 'url': 'http://twitter.com/search?q=%E7%A2%BA%E5%AE%9A%E7%94%B3%E5%91%8A%E7%B7%A0%E3%82%81', 'promoted_content': None, 'query': '%E7%A2%BA%E5%AE%9A%E7%94%B3%E5%91%8A%E7%B7%A0%E3%82%81', 'tweet_volume': None}
# {'name': 'White Day', 'url': 'http://twitter.com/search?q=%22White+Day%22', 'promoted_content': None, 'query': '%22White+Day%22', 'tweet_volume': 247092}
# {'name': "IT'S RACE WEEK", 'url': 'http://twitter.com/search?q=%22IT%27S+RACE+WEEK%22', 'promoted_content': None, 'query': '%22IT%27S+RACE+WEEK%22', 'tweet_volume': None}
# {'name': 'うぉーあい', 'url': 'http://twitter.com/search?q=%E3%81%86%E3%81%89%E3%83%BC%E3%81%82%E3%81%84', 'promoted_content': None, 'query': '%E3%81%86%E3%81%89%E3%83%BC%E3%81%82%E3%81%84', 'tweet_volume': None}
# {'name': 'Pulse Asia', 'url': 'http://twitter.com/search?q=%22Pulse+Asia%22', 'promoted_content': None, 'query': '%22Pulse+Asia%22', 'tweet_volume': None}
# {'name': 'クーラー', 'url': 'http://twitter.com/search?q=%E3%82%AF%E3%83%BC%E3%83%A9%E3%83%BC', 'promoted_content': None, 'query': '%E3%82%AF%E3%83%BC%E3%83%A9%E3%83%BC', 'tweet_volume': None}

# %% [markdown]
# Add all trends words into a list

# %%
bag_of_trending_words = []

for trend in twitter_trends:
  if trend['name'] not in bag_of_trending_words :
    # ignore duplicates (twitter API bug? sometimes trends are duplicated) 
    if trend['name'][0:1] != '#':
      bag_of_trending_words.append(trend['name'])
    # else:
      # split hashtag and add to array

print(bag_of_trending_words)
# Out:
# ['Fabianski', 'Farmaajo', 'Toffees', 'Anthony Gordon', 'Coufal', 'Mavs', 'Rodrigo', 'Wilf', 'Erin Cuthbert', 'Edgeley Park', 'Fernandinho', 'Zinchenko', 'Pascal', 'Manchester City', 'Buffalo', 'Everton', 'Donna', 'Rondon', 'David Tennant', 'Richarlison', 'Theo Hernandez', 'Palace', 'West Ham', 'Mahrez', 'Branthwaite', 'Michael Oliver', 'Gomes', 'Eriksen', 'Burnley', 'Angel Delight', 'Trifle', 'Doucoure', 'Rico Henry', 'Southampton', 'Stockport', 'Bowen', 'Arctic Roll', 'Frank Lampard', 'Joffy', 'Grantham', 'Goodison', 'Wrexham', 'Toney', 'Gerrard']

# %% [markdown]
# ## Store Data in MongoDB Database

# %%
import time
from datetime import date, datetime

# sleep for 4 hours
for i in range(1):
  print("fetch trends ", i)

  twitter_trends = fetch_twitter_trends(twitter_woeid)
  # twitter_trends = fetch_twitter_trends(woeid=2282863)

  # twitter_trends = [{'name': 'Ronaldo', 'url': 'http://twitter.com/search?q=Ronaldo', 'promoted_content': None, 'query': 'Ronaldo', 'tweet_volume': 714522}, {'name': 'Maguire', 'url': 'http://twitter.com/search?q=Maguire', 'promoted_content': None, 'query': 'Maguire', 'tweet_volume': 157809}, {'name': '#MUNTOT', 'url': 'http://twitter.com/search?q=%23MUNTOT', 'promoted_content': None, 'query': '%23MUNTOT', 'tweet_volume': 209811}, {'name': '#CR7𓃵', 'url': 'http://twitter.com/search?q=%23CR7%F0%93%83%B5', 'promoted_content': None, 'query': '%23CR7%F0%93%83%B5', 'tweet_volume': 50826}, {'name': 'Pogba', 'url': 'http://twitter.com/search?q=Pogba', 'promoted_content': None, 'query': 'Pogba', 'tweet_volume': 47340}, {'name': '#MUFC', 'url': 'http://twitter.com/search?q=%23MUFC', 'promoted_content': None, 'query': '%23MUFC', 'tweet_volume': 187744}, {'name': 'Spurs', 'url': 'http://twitter.com/search?q=Spurs', 'promoted_content': None, 'query': 'Spurs', 'tweet_volume': 132987}, {'name': 'Browns', 'url': 'http://twitter.com/search?q=Browns', 'promoted_content': None, 'query': 'Browns', 'tweet_volume': 47885}, {'name': 'Sancho', 'url': 'http://twitter.com/search?q=Sancho', 'promoted_content': None, 'query': 'Sancho', 'tweet_volume': 46210}, {'name': 'Tottenham', 'url': 'http://twitter.com/search?q=Tottenham', 'promoted_content': None, 'query': 'Tottenham', 'tweet_volume': 160537}, {'name': 'Amari Cooper', 'url': 'http://twitter.com/search?q=%22Amari+Cooper%22', 'promoted_content': None, 'query': '%22Amari+Cooper%22', 'tweet_volume': 38774}, {'name': '#ENGvIRE', 'url': 'http://twitter.com/search?q=%23ENGvIRE', 'promoted_content': None, 'query': '%23ENGvIRE', 'tweet_volume': 16816}, {'name': 'GOAT', 'url': 'http://twitter.com/search?q=GOAT', 'promoted_content': None, 'query': 'GOAT', 'tweet_volume': 169233}, {'name': '#melfest', 'url': 'http://twitter.com/search?q=%23melfest', 'promoted_content': None, 'query': '%23melfest', 'tweet_volume': 12851}, {'name': 'Cowboys', 'url': 'http://twitter.com/search?q=Cowboys', 'promoted_content': None, 'query': 'Cowboys', 'tweet_volume': 45403}, {'name': 'رونالدو', 'url': 'http://twitter.com/search?q=%D8%B1%D9%88%D9%86%D8%A7%D9%84%D8%AF%D9%88', 'promoted_content': None, 'query': '%D8%B1%D9%88%D9%86%D8%A7%D9%84%D8%AF%D9%88', 'tweet_volume': 39695}, {'name': 'Rashford', 'url': 'http://twitter.com/search?q=Rashford', 'promoted_content': None, 'query': 'Rashford', 'tweet_volume': 41258}, {'name': 'Romero', 'url': 'http://twitter.com/search?q=Romero', 'promoted_content': None, 'query': 'Romero', 'tweet_volume': 30256}, {'name': 'Baker', 'url': 'http://twitter.com/search?q=Baker', 'promoted_content': None, 'query': 'Baker', 'tweet_volume': 31689}, {'name': 'Bohannon', 'url': 'http://twitter.com/search?q=Bohannon', 'promoted_content': None, 'query': 'Bohannon', 'tweet_volume': None}, {'name': 'Iowa', 'url': 'http://twitter.com/search?q=Iowa', 'promoted_content': None, 'query': 'Iowa', 'tweet_volume': 30507}, {'name': 'Telles', 'url': 'http://twitter.com/search?q=Telles', 'promoted_content': None, 'query': 'Telles', 'tweet_volume': 13115}, {'name': 'Traci', 'url': 'http://twitter.com/search?q=Traci', 'promoted_content': None, 'query': 'Traci', 'tweet_volume': 72009}, {'name': 'Old Trafford', 'url': 'http://twitter.com/search?q=%22Old+Trafford%22', 'promoted_content': None, 'query': '%22Old+Trafford%22', 'tweet_volume': 40693}, {'name': 'Matic', 'url': 'http://twitter.com/search?q=Matic', 'promoted_content': None, 'query': 'Matic', 'tweet_volume': 144277}, {'name': 'TURMA DA GKAY NO MION', 'url': 'http://twitter.com/search?q=%22TURMA+DA+GKAY+NO+MION%22', 'promoted_content': None, 'query': '%22TURMA+DA+GKAY+NO+MION%22', 'tweet_volume': None}, {'name': 'Will Wade', 'url': 'http://twitter.com/search?q=%22Will+Wade%22', 'promoted_content': None, 'query': '%22Will+Wade%22', 'tweet_volume': None}, {'name': 'Tom Brady', 'url': 'http://twitter.com/search?q=%22Tom+Brady%22', 'promoted_content': None, 'query': '%22Tom+Brady%22', 'tweet_volume': 11898}, {'name': 'Cleveland', 'url': 'http://twitter.com/search?q=Cleveland', 'promoted_content': None, 'query': 'Cleveland', 'tweet_volume': 24828}, {'name': 'Kane', 'url': 'http://twitter.com/search?q=Kane', 'promoted_content': None, 'query': 'Kane', 'tweet_volume': 57987}, {'name': 'Landry', 'url': 'http://twitter.com/search?q=Landry', 'promoted_content': None, 'query': 'Landry', 'tweet_volume': None}, {'name': 'Hat-trick', 'url': 'http://twitter.com/search?q=Hat-trick', 'promoted_content': None, 'query': 'Hat-trick', 'tweet_volume': 75079}, {'name': 'Dier', 'url': 'http://twitter.com/search?q=Dier', 'promoted_content': None, 'query': 'Dier', 'tweet_volume': None}, {'name': 'Cornelia', 'url': 'http://twitter.com/search?q=Cornelia', 'promoted_content': None, 'query': 'Cornelia', 'tweet_volume': None}, {'name': 'Texas A&M', 'url': 'http://twitter.com/search?q=%22Texas+A%26M%22', 'promoted_content': None, 'query': '%22Texas+A%26M%22', 'tweet_volume': None}, {'name': 'Ororo', 'url': 'http://twitter.com/search?q=Ororo', 'promoted_content': None, 'query': 'Ororo', 'tweet_volume': 10068}, {'name': 'Campaz', 'url': 'http://twitter.com/search?q=Campaz', 'promoted_content': None, 'query': 'Campaz', 'tweet_volume': None}, {'name': 'Bentancur', 'url': 'http://twitter.com/search?q=Bentancur', 'promoted_content': None, 'query': 'Bentancur', 'tweet_volume': None}, {'name': 'Gallup', 'url': 'http://twitter.com/search?q=Gallup', 'promoted_content': None, 'query': 'Gallup', 'tweet_volume': None}, {'name': 'كريستيانو', 'url': 'http://twitter.com/search?q=%D9%83%D8%B1%D9%8A%D8%B3%D8%AA%D9%8A%D8%A7%D9%86%D9%88', 'promoted_content': None, 'query': '%D9%83%D8%B1%D9%8A%D8%B3%D8%AA%D9%8A%D8%A7%D9%86%D9%88', 'tweet_volume': 19663}, {'name': 'Keegan Murray', 'url': 'http://twitter.com/search?q=%22Keegan+Murray%22', 'promoted_content': None, 'query': '%22Keegan+Murray%22', 'tweet_volume': None}, {'name': 'Thuli P', 'url': 'http://twitter.com/search?q=%22Thuli+P%22', 'promoted_content': None, 'query': '%22Thuli+P%22', 'tweet_volume': None}, {'name': 'Lloris', 'url': 'http://twitter.com/search?q=Lloris', 'promoted_content': None, 'query': 'Lloris', 'tweet_volume': None}, {'name': 'El Bicho', 'url': 'http://twitter.com/search?q=%22El+Bicho%22', 'promoted_content': None, 'query': '%22El+Bicho%22', 'tweet_volume': 13613}, {'name': '#الاهلي_الطايي', 'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A_%D8%A7%D9%84%D8%B7%D8%A7%D9%8A%D9%8A', 'promoted_content': None, 'query': '%23%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A_%D8%A7%D9%84%D8%B7%D8%A7%D9%8A%D9%8A', 'tweet_volume': 46852}, {'name': '#İstanbulkar', 'url': 'http://twitter.com/search?q=%23%C4%B0stanbulkar', 'promoted_content': None, 'query': '%23%C4%B0stanbulkar', 'tweet_volume': None}, {'name': '#GönülDağı', 'url': 'http://twitter.com/search?q=%23G%C3%B6n%C3%BClDa%C4%9F%C4%B1', 'promoted_content': None, 'query': '%23G%C3%B6n%C3%BClDa%C4%9F%C4%B1', 'tweet_volume': None}, {'name': '#ManUtd', 'url': 'http://twitter.com/search?q=%23ManUtd', 'promoted_content': None, 'query': '%23ManUtd', 'tweet_volume': None}, {'name': '#imamoğluistifa', 'url': 'http://twitter.com/search?q=%23imamo%C4%9Fluistifa', 'promoted_content': None, 'query': '%23imamo%C4%9Fluistifa', 'tweet_volume': None}, {'name': '#GGMU', 'url': 'http://twitter.com/search?q=%23GGMU', 'promoted_content': None, 'query': '%23GGMU', 'tweet_volume': None}]
  # print(twitter_trends)

  # add datetime
  # today = date.today()
  # t = time.localtime()
  # current_time = time.strftime("%H:%M:%S", t)
  # print("Date:", today, "\nTime:", current_time)
  created_datetime = datetime.today().replace(microsecond=0)

  # 13/Mar/2022 - 2AM
  # datetime(year, month, day, hour, minute, second, microsecond)
  # created_datetime = datetime(2022, 3, 13, 14, 0, 0, 0)
  print("datetime", created_datetime)

  for trend in twitter_trends:
    trend['created_datetime'] = created_datetime
    trend['woeid'] = twitter_woeid
    # print(trend)

  # store in mongodb
  trends_collection.insert_many(twitter_trends)

  # time.sleep(5)
  # time.sleep(14400)
# Out:
# fetch trends  0
# datetime 2022-05-15 19:05:30

# %% [markdown]
# # Identify Trend Sentiment & Categories

# %% [markdown]
# ## Get All Twitter trends from MongoDB Collection
#
# *only get trends with no sentiment & categories (not preprocessed before)*

# %%
twitter_trends = []

for x in trends_collection.find():
  # pp.pprint(x)
  twitter_trends.append(x)

len(twitter_trends)
# Out:
# 774

# %% [markdown]
# ## Fetch Tweets from Twitter
#
# Get top 4 tweets, to calculate an average sentiment score

# %%
twitter_trends[0]
# Out:
# {'_id': ObjectId('622e388aee4a66d5042f8697'),
#  'created_datetime': datetime.datetime(2022, 2, 28, 13, 0),
#  'name': '#โหนกระเเส',
#  'promoted_content': None,
#  'query': '%23%E0%B9%82%E0%B8%AB%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B9%80%E0%B8%AA',
#  'sentiment_score': 0.762,
#  'tweet_volume': 2166180,
#  'url': 'http://twitter.com/search?q=%23%E0%B9%82%E0%B8%AB%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B9%80%E0%B8%AA',
#  'woeid': 1}

# %% [markdown]
# ## Sentiment Analysis using *SpacyTextBlob*

# %%
# !pip install spacytextblob
# !python -m textblob.download_corpora
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacytextblob in /usr/local/lib/python3.7/dist-packages (4.0.0)
# Requirement already satisfied: spacy<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from spacytextblob) (3.2.3)
# Requirement already satisfied: textblob<0.16.0,>=0.15.3 in /usr/local/lib/python3.7/dist-packages (from spacytextblob) (0.15.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (2.11.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (0.6.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (1.0.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (3.10.0.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (3.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (57.4.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (0.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (21.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (8.0.15)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (4.63.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (1.21.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (2.4.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (0.9.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (0.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (1.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (3.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (2.23.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0,>=3.0->spacytextblob) (1.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<4.0,>=3.0->spacytextblob) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<4.0,>=3.0->spacytextblob) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<4.0,>=3.0->spacytextblob) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.0->spacytextblob) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.0->spacytextblob) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.0->spacytextblob) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.0->spacytextblob) (3.0.4)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.7/dist-packages (from textblob<0.16.0,>=0.15.3->spacytextblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob<0.16.0,>=0.15.3->spacytextblob) (1.15.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<4.0,>=3.0->spacytextblob) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<4.0,>=3.0->spacytextblob) (2.0.1)
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 3.2 MB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==3.2.0) (3.2.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (57.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.15)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.23.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.21.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.63.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
text = 'I had a really horrible day. It was the worst day ever! But every now and then I have a really good day that makes me happy.'
# text = 'I hate her'
doc = nlp(text)
doc._.blob.polarity                            # Polarity: -0.125.  # <-this gives the sentiment
print(doc._.blob.polarity)
doc._.blob.subjectivity                        # Subjectivity: 0.9
doc._.blob.sentiment_assessments.assessments   # Assessments: [(['really', 'horrible'], -1.0, 1.0, None), (['worst', '!'], -1.0, 1.0, None), (['really', 'good'], 0.7, 0.6000000000000001, None), (['happy'], 0.8, 1.0, None)]
doc._.blob.ngrams()                            # [WordList(['I', 'had', 'a']), WordList(['had', 'a', 'really']), WordList(['a', 'really', 'horrible']), WordList(['really', 'horrible', 'day']), WordList(['horrible', 'day', 'It']), WordList(['day', 'It', 'was']), WordList(['It', 'was', 'the']), WordList(['was', 'the', 'worst']), WordList(['the', 'worst', 'day']), WordList(['worst', 'day', 'ever']), WordList(['day', 'ever', 'But']), WordList(['ever', 'But', 'every']), WordList(['But', 'every', 'now']), WordList(['every', 'now', 'and']), WordList(['now', 'and', 'then']), WordList(['and', 'then', 'I']), WordList(['then', 'I', 'have']), WordList(['I', 'have', 'a']), WordList(['have', 'a', 'really']), WordList(['a', 'really', 'good']), WordList(['really', 'good', 'day']), WordList(['good', 'day', 'that']), WordList(['day', 'that', 'makes']), WordList(['that', 'makes', 'me']), WordList(['makes', 'me', 'happy'])]
# Out:
# -0.125
# [WordList(['I', 'had', 'a']),
#  WordList(['had', 'a', 'really']),
#  WordList(['a', 'really', 'horrible']),
#  WordList(['really', 'horrible', 'day']),
#  WordList(['horrible', 'day', 'It']),
#  WordList(['day', 'It', 'was']),
#  WordList(['It', 'was', 'the']),
#  WordList(['was', 'the', 'worst']),
#  WordList(['the', 'worst', 'day']),
#  WordList(['worst', 'day', 'ever']),
#  WordList(['day', 'ever', 'But']),
#  WordList(['ever', 'But', 'every']),
#  WordList(['But', 'every', 'now']),
#  WordList(['every', 'now', 'and']),
#  WordList(['now', 'and', 'then']),
#  WordList(['and', 'then', 'I']),
#  WordList(['then', 'I', 'have']),
#  WordList(['I', 'have', 'a']),
#  WordList(['have', 'a', 'really']),
#  WordList(['a', 'really', 'good']),
#  WordList(['really', 'good', 'day']),
#  WordList(['good', 'day', 'that']),
#  WordList(['day', 'that', 'makes']),
#  WordList(['that', 'makes', 'me']),
#  WordList(['makes', 'me', 'happy'])]

# %% [markdown]
# ## Sentiment Analysis using *HappyTransformer*
# Built on *Hugging Face*'s transformers library

# %%
# !pip install happytransformer

# %%
from happytransformer import HappyTextClassification

# %%
happy_tc = HappyTextClassification(model_type="DISTILBERT", model_name="distilbert-base-uncased-finetuned-sst-2-english", num_labels=2)
# Out:
# 03/17/2022 13:46:44 - INFO - happytransformer.happy_transformer -   Using model: cpu

# %%
result = happy_tc.classify_text("I love AI")
print(result)
# Out:
# TextClassificationResult(label='POSITIVE', score=0.9998302459716797)

# %%
result_2 = happy_tc.classify_text("I hate tomatoes")
print(result_2)
# Out:
# TextClassificationResult(label='NEGATIVE', score=0.9987173080444336)

# %%
text = 'I had a really horrible day. It was the worst day ever! But every now and then I have a really good day that makes me happy.'
result_3 = happy_tc.classify_text(text)
print(result_3)
# Out:
# TextClassificationResult(label='POSITIVE', score=0.9998552799224854)

# %% [markdown]
# ## Twitter-roBERTa-base for Sentiment Analysis
# Sentiment Analysis model built & trained for tweets
#
# https://huggingface.co/cardiffnlp/twitter-roberta-base-sentiment#twitter-roberta-base-for-sentiment-analysis
#
#
# **This is the best & it's insanely fast as well!!**

# %%
# !pip install torch
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.19.1-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 24.9 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.6.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.9 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 33.6 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 45.6 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.6.0 pyyaml-6.0 tokenizers-0.12.1 transformers-4.19.1

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer
import numpy as np
from scipy.special import softmax
import csv
import urllib.request

# %%
# Preprocess text (username and link placeholders)
def preprocess(text):
    new_text = []
 
 
    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

# Tasks:
# emoji, emotion, hate, irony, offensive, sentiment
# stance/abortion, stance/atheism, stance/climate, stance/feminist, stance/hillary

task='sentiment'
MODEL = f"cardiffnlp/twitter-roberta-base-{task}"

tokenizer = AutoTokenizer.from_pretrained(MODEL)

# download label mapping
labels=[]
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels = [row[1] for row in csvreader if len(row) > 1]

# PT
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
model.save_pretrained(MODEL)
tokenizer.save_pretrained(MODEL) # https://stackoverflow.com/a/67246204/11005638
# Out:
# Downloading:   0%|          | 0.00/747 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/476M [00:00<?, ?B/s]
# ('cardiffnlp/twitter-roberta-base-sentiment/tokenizer_config.json',
#  'cardiffnlp/twitter-roberta-base-sentiment/special_tokens_map.json',
#  'cardiffnlp/twitter-roberta-base-sentiment/vocab.json',
#  'cardiffnlp/twitter-roberta-base-sentiment/merges.txt',
#  'cardiffnlp/twitter-roberta-base-sentiment/added_tokens.json',
#  'cardiffnlp/twitter-roberta-base-sentiment/tokenizer.json')

# %%
def analyse_sentiment(text):
  # text = "Good night 😊"
  # text = 'I had a really horrible day. It was the worst day ever! But every now and then I have a really good day that makes me happy.'
  # text = "I'm Ok"

  text = preprocess(text)
  encoded_input = tokenizer(text, return_tensors='pt')
  output = model(**encoded_input)
  scores = output[0][0].detach().numpy()
  scores = softmax(scores)

  # # TF
  # model = TFAutoModelForSequenceClassification.from_pretrained(MODEL)
  # model.save_pretrained(MODEL)

  # text = "Good night 😊"
  # encoded_input = tokenizer(text, return_tensors='tf')
  # output = model(encoded_input)
  # scores = output[0][0].numpy()
  # scores = softmax(scores)

  ranking = np.argsort(scores)
  ranking = ranking[::-1]

  print(labels[ranking[0]], scores[ranking[0]])

  highest_ranked_label = labels[ranking[0]]
  highest_ranked_score = scores[ranking[0]]

  if highest_ranked_label == "negative":
    print(f"{highest_ranked_label} sentiment")
    return - np.round(highest_ranked_score, 4) # round the output to 4 decimal places
  elif highest_ranked_label == "neutral":
    print(f"{highest_ranked_label} sentiment")
    return np.round(highest_ranked_score, 4) # round the output to 4 decimal places
  elif highest_ranked_label == "positive":
    print(f"{highest_ranked_label} sentiment")
    return 2*np.round(highest_ranked_score, 4) # round the output to 4 decimal places
  
  # for i in range(scores.shape[0]):
  #     l = labels[ranking[i]]
  #     s = scores[ranking[i]]
  #     print(f"{i+1}) {l} {np.round(float(s), 4)}")

# %% [markdown]
# get the val of the label that gives the highest score (positive/ negative/ neutral).
#
# positive score is multiplied by 2, to give 0-1 range for neutral sentiment.
#
# The highest value is given by the first output

# %%
# text = "Good night 😊"
text = 'I had a really horrible day. It was the worst day ever! But every now and then I have a really good day that makes me happy.'
# text = "I'm Ok"

analyse_sentiment(text)
# Out:
# negative 0.62066644
# negative sentiment
# -0.6207

# %%
def search_popular_tweets(query, count):
  url = f"https://api.twitter.com/1.1/search/tweets.json?q={query}&result_type=popular&count={count}"

  payload={}
  headers = {
    'authorization': 'Bearer ' + auth_token,
    'Cookie': 'guest_id=v1%3A164302265238123185; guest_id_ads=v1%3A164302265238123185; guest_id_marketing=v1%3A164302265238123185; personalization_id="v1_7SOW+P3aER3WzxCMuCXiWw=="'
  }

  response = requests.request("GET", url, headers=headers, data=payload)

  if response.status_code != 200:
    print('error')

  tweets = response.json()['statuses']

  # pp.pprint(tweets)

  tweets_text = []
  
  for tweet in tweets:
    tweets_text.append(tweet['text'])

  # may have to serialize/ deserialize these senteces \n \u etc might not be recognized properly by the sentiment analysis model?

  return tweets_text

# search_popular_tweets('%23Ireland', 4)

# %%
for trend in twitter_trends:
  # check if trend.sentiment == None:
  if 'sentiment_score' not in trend:
    print(trend)

    max_tweet_count = 4
    # get top 4 tweets
    top_tweets = search_popular_tweets(trend['query'], 4)

    if len(top_tweets) != 0:
      total_sentiment_score = 0
      # apply sentiment analysis.
      for top_tweet in top_tweets:
        tweet_sentiment_score = analyse_sentiment(top_tweet)
        total_sentiment_score += tweet_sentiment_score
        print('tweet_sentiment_score:', tweet_sentiment_score)

      # TODO EXTRA: get annotated fields from twitter for each tweet - have this separately

      # get an average for sentiment score
      average_sentiment_score = total_sentiment_score/ len(top_tweets)
      print('total_sentiment_score:', total_sentiment_score)
      # print('average_sentiment_score:', average_sentiment_score)
    else:
      average_sentiment_score = 1 # always between neutral and positive

    # update trend's sentiment score in mongodb
    rounded_sentiment_score = round(average_sentiment_score,4)
    myquery = { "_id": trend["_id"] }
    newvalues = { "$set": { "sentiment_score": rounded_sentiment_score } }

    trends_collection.update_one(myquery, newvalues)
# Out:
# {'_id': ObjectId('627ecb207ea96d6a094d4c8d'), 'name': 'Kenilworth Road', 'url': 'http://twitter.com/search?q=%22Kenilworth+Road%22', 'promoted_content': None, 'query': '%22Kenilworth+Road%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# positive 0.9385914
# positive sentiment
# tweet_sentiment_score: 1.8772000074386597
# positive 0.6091384
# positive sentiment
# tweet_sentiment_score: 1.2181999683380127
# neutral 0.651595
# neutral sentiment
# tweet_sentiment_score: 0.6516
# neutral 0.7377244
# neutral sentiment
# tweet_sentiment_score: 0.7377
# total_sentiment_score: 4.484699964523315
# {'_id': ObjectId('627ecb207ea96d6a094d4c9a'), 'name': 'Luton', 'url': 'http://twitter.com/search?q=Luton', 'promoted_content': None, 'query': 'Luton', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# negative 0.90849334
# negative sentiment
# tweet_sentiment_score: -0.9085
# positive 0.54371095
# positive sentiment
# tweet_sentiment_score: 1.087399959564209
# neutral 0.5749561
# neutral sentiment
# tweet_sentiment_score: 0.575
# neutral 0.74486005
# neutral sentiment
# tweet_sentiment_score: 0.7449
# total_sentiment_score: 1.4987999200820923
# {'_id': ObjectId('627ecb207ea96d6a094d4c96'), 'name': 'Willie Collum', 'url': 'http://twitter.com/search?q=%22Willie+Collum%22', 'promoted_content': None, 'query': '%22Willie+Collum%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# {'_id': ObjectId('627ecb207ea96d6a094d4c90'), 'name': '#FridayVibes', 'url': 'http://twitter.com/search?q=%23FridayVibes', 'promoted_content': None, 'query': '%23FridayVibes', 'tweet_volume': 14377, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# positive 0.89546305
# positive sentiment
# tweet_sentiment_score: 1.7910000085830688
# neutral 0.8901509
# neutral sentiment
# tweet_sentiment_score: 0.8902
# neutral 0.6791959
# neutral sentiment
# tweet_sentiment_score: 0.6792
# neutral 0.84366643
# neutral sentiment
# tweet_sentiment_score: 0.8437
# total_sentiment_score: 4.204100012779236
# {'_id': ObjectId('627ecb207ea96d6a094d4ca0'), 'name': 'Fred Ward', 'url': 'http://twitter.com/search?q=%22Fred+Ward%22', 'promoted_content': None, 'query': '%22Fred+Ward%22', 'tweet_volume': 27325, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# negative 0.57263356
# negative sentiment
# tweet_sentiment_score: -0.5726
# neutral 0.61581594
# neutral sentiment
# tweet_sentiment_score: 0.6158
# positive 0.60849386
# positive sentiment
# tweet_sentiment_score: 1.2170000076293945
# neutral 0.6111991
# neutral sentiment
# tweet_sentiment_score: 0.6112
# total_sentiment_score: 1.871399998664856
# {'_id': ObjectId('627ecb207ea96d6a094d4c9f'), 'name': 'Semtex', 'url': 'http://twitter.com/search?q=Semtex', 'promoted_content': None, 'query': 'Semtex', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# positive 0.7321195
# positive sentiment
# tweet_sentiment_score: 1.4642000198364258
# positive 0.8113828
# positive sentiment
# tweet_sentiment_score: 1.6227999925613403
# positive 0.90483147
# positive sentiment
# tweet_sentiment_score: 1.8095999956130981
# positive 0.9901669
# positive sentiment
# tweet_sentiment_score: 1.9803999662399292
# total_sentiment_score: 6.8769999742507935
# {'_id': ObjectId('627ecb207ea96d6a094d4c94'), 'name': 'Viera', 'url': 'http://twitter.com/search?q=Viera', 'promoted_content': None, 'query': 'Viera', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.77084804
# neutral sentiment
# tweet_sentiment_score: 0.7708
# neutral 0.87780666
# neutral sentiment
# tweet_sentiment_score: 0.8778
# neutral 0.8573111
# neutral sentiment
# tweet_sentiment_score: 0.8573
# neutral 0.7794089
# neutral sentiment
# tweet_sentiment_score: 0.7794
# total_sentiment_score: 3.2852999567985535
# {'_id': ObjectId('627ecb207ea96d6a094d4c8f'), 'name': 'Wakefield', 'url': 'http://twitter.com/search?q=Wakefield', 'promoted_content': None, 'query': 'Wakefield', 'tweet_volume': 14621, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.7232012
# neutral sentiment
# tweet_sentiment_score: 0.7232
# negative 0.60844207
# negative sentiment
# tweet_sentiment_score: -0.6084
# neutral 0.6382109
# neutral sentiment
# tweet_sentiment_score: 0.6382
# neutral 0.62991124
# neutral sentiment
# tweet_sentiment_score: 0.6299
# total_sentiment_score: 1.3828999996185303
# {'_id': ObjectId('627ecb207ea96d6a094d4ca3'), 'name': 'Nathan Jones', 'url': 'http://twitter.com/search?q=%22Nathan+Jones%22', 'promoted_content': None, 'query': '%22Nathan+Jones%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.896444
# neutral sentiment
# tweet_sentiment_score: 0.8964
# positive 0.97457945
# positive sentiment
# tweet_sentiment_score: 1.9492000341415405
# positive 0.8236916
# positive sentiment
# tweet_sentiment_score: 1.6474000215530396
# positive 0.9873644
# positive sentiment
# tweet_sentiment_score: 1.9747999906539917
# total_sentiment_score: 6.46780002117157
# {'_id': ObjectId('627ecb207ea96d6a094d4c91'), 'name': 'Keown', 'url': 'http://twitter.com/search?q=Keown', 'promoted_content': None, 'query': 'Keown', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.7157574
# neutral sentiment
# tweet_sentiment_score: 0.7158
# neutral 0.48260406
# neutral sentiment
# tweet_sentiment_score: 0.4826
# neutral 0.5218734
# neutral sentiment
# tweet_sentiment_score: 0.5219
# neutral 0.64968604
# neutral sentiment
# tweet_sentiment_score: 0.6497
# total_sentiment_score: 2.369999974966049
# {'_id': ObjectId('627ecb207ea96d6a094d4c8b'), 'name': 'Albion', 'url': 'http://twitter.com/search?q=Albion', 'promoted_content': None, 'query': 'Albion', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# positive 0.5225158
# positive sentiment
# tweet_sentiment_score: 1.0449999570846558
# neutral 0.8564051
# neutral sentiment
# tweet_sentiment_score: 0.8564
# positive 0.892478
# positive sentiment
# tweet_sentiment_score: 1.784999966621399
# neutral 0.85871595
# neutral sentiment
# tweet_sentiment_score: 0.8587
# total_sentiment_score: 4.545099914073944
# {'_id': ObjectId('627ecb207ea96d6a094d4c8c'), 'name': 'Reynolds', 'url': 'http://twitter.com/search?q=Reynolds', 'promoted_content': None, 'query': 'Reynolds', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.81937677
# neutral sentiment
# tweet_sentiment_score: 0.8194
# neutral 0.7317243
# neutral sentiment
# tweet_sentiment_score: 0.7317
# neutral 0.8806228
# neutral sentiment
# tweet_sentiment_score: 0.8806
# negative 0.615083
# negative sentiment
# tweet_sentiment_score: -0.6151
# total_sentiment_score: 1.81659996509552
# {'_id': ObjectId('627ecb207ea96d6a094d4cba'), 'name': 'Palestinian', 'url': 'http://twitter.com/search?q=Palestinian', 'promoted_content': None, 'query': 'Palestinian', 'tweet_volume': 206906, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# negative 0.82732743
# negative sentiment
# tweet_sentiment_score: -0.8273
# negative 0.4983731
# negative sentiment
# tweet_sentiment_score: -0.4984
# negative 0.8860825
# negative sentiment
# tweet_sentiment_score: -0.8861
# negative 0.60525197
# negative sentiment
# tweet_sentiment_score: -0.6053
# total_sentiment_score: -2.817100018262863
# {'_id': ObjectId('627ecb207ea96d6a094d4c99'), 'name': 'Arbroath', 'url': 'http://twitter.com/search?q=Arbroath', 'promoted_content': None, 'query': 'Arbroath', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# negative 0.93966824
# negative sentiment
# tweet_sentiment_score: -0.9397
# positive 0.50146455
# positive sentiment
# tweet_sentiment_score: 1.003000020980835
# neutral 0.76150167
# neutral sentiment
# tweet_sentiment_score: 0.7615
# neutral 0.68251896
# neutral sentiment
# tweet_sentiment_score: 0.6825
# total_sentiment_score: 1.5073000192642212
# {'_id': ObjectId('627ecb207ea96d6a094d4ca2'), 'name': 'boney m', 'url': 'http://twitter.com/search?q=%22boney+m%22', 'promoted_content': None, 'query': '%22boney+m%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# {'_id': ObjectId('627ecb207ea96d6a094d4ca6'), 'name': 'Katie Hopkins', 'url': 'http://twitter.com/search?q=%22Katie+Hopkins%22', 'promoted_content': None, 'query': '%22Katie+Hopkins%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# negative 0.5128227
# negative sentiment
# tweet_sentiment_score: -0.5128
# neutral 0.4978838
# neutral sentiment
# tweet_sentiment_score: 0.4979
# positive 0.943714
# positive sentiment
# tweet_sentiment_score: 1.8874000310897827
# negative 0.5455178
# negative sentiment
# tweet_sentiment_score: -0.5455
# total_sentiment_score: 1.327000081539154
# {'_id': ObjectId('627ecb207ea96d6a094d4cab'), 'name': 'Josh Kelly', 'url': 'http://twitter.com/search?q=%22Josh+Kelly%22', 'promoted_content': None, 'query': '%22Josh+Kelly%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.9269183
# neutral sentiment
# tweet_sentiment_score: 0.9269
# neutral 0.92372936
# neutral sentiment
# tweet_sentiment_score: 0.9237
# neutral 0.91446984
# neutral sentiment
# tweet_sentiment_score: 0.9145
# total_sentiment_score: 2.7651000022888184
# {'_id': ObjectId('627ecb207ea96d6a094d4c9b'), 'name': 'Paul Daley', 'url': 'http://twitter.com/search?q=%22Paul+Daley%22', 'promoted_content': None, 'query': '%22Paul+Daley%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# positive 0.8113828
# positive sentiment
# tweet_sentiment_score: 1.6227999925613403
# positive 0.9411366
# positive sentiment
# tweet_sentiment_score: 1.882200002670288
# positive 0.8407147
# positive sentiment
# tweet_sentiment_score: 1.681399941444397
# negative 0.5925482
# negative sentiment
# tweet_sentiment_score: -0.5925
# total_sentiment_score: 4.593899965286255
# {'_id': ObjectId('627ecb207ea96d6a094d4ca5'), 'name': 'St Johnstone', 'url': 'http://twitter.com/search?q=%22St+Johnstone%22', 'promoted_content': None, 'query': '%22St+Johnstone%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.841147
# neutral sentiment
# tweet_sentiment_score: 0.8411
# total_sentiment_score: 0.8410999774932861
# {'_id': ObjectId('627ecb207ea96d6a094d4cb0'), 'name': 'Nazanin', 'url': 'http://twitter.com/search?q=Nazanin', 'promoted_content': None, 'query': 'Nazanin', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.60486126
# neutral sentiment
# tweet_sentiment_score: 0.6049
# positive 0.7208225
# positive sentiment
# tweet_sentiment_score: 1.44159996509552
# negative 0.9166105
# negative sentiment
# tweet_sentiment_score: -0.9166
# neutral 0.5860868
# neutral sentiment
# tweet_sentiment_score: 0.5861
# total_sentiment_score: 1.715999960899353
# {'_id': ObjectId('627ecb207ea96d6a094d4cb2'), 'name': 'Sonny Bradley', 'url': 'http://twitter.com/search?q=%22Sonny+Bradley%22', 'promoted_content': None, 'query': '%22Sonny+Bradley%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.5749561
# neutral sentiment
# tweet_sentiment_score: 0.575
# positive 0.5854833
# positive sentiment
# tweet_sentiment_score: 1.1710000038146973
# total_sentiment_score: 1.7459999918937683
# {'_id': ObjectId('627ecb207ea96d6a094d4cb1'), 'name': 'Gayfield', 'url': 'http://twitter.com/search?q=Gayfield', 'promoted_content': None, 'query': 'Gayfield', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.53987396
# neutral sentiment
# tweet_sentiment_score: 0.5399
# total_sentiment_score: 0.539900004863739
# {'_id': ObjectId('627ecb207ea96d6a094d4cb3'), 'name': 'Simply Red', 'url': 'http://twitter.com/search?q=%22Simply+Red%22', 'promoted_content': None, 'query': '%22Simply+Red%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# {'_id': ObjectId('627ecb207ea96d6a094d4c95'), 'name': 'Perisic', 'url': 'http://twitter.com/search?q=Perisic', 'promoted_content': None, 'query': 'Perisic', 'tweet_volume': 18422, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.86275566
# neutral sentiment
# tweet_sentiment_score: 0.8628
# neutral 0.88968325
# neutral sentiment
# tweet_sentiment_score: 0.8897
# neutral 0.68062377
# neutral sentiment
# tweet_sentiment_score: 0.6806
# neutral 0.867382
# neutral sentiment
# tweet_sentiment_score: 0.8674
# total_sentiment_score: 3.300499975681305
# {'_id': ObjectId('627ecb207ea96d6a094d4c98'), 'name': '#Bellator281', 'url': 'http://twitter.com/search?q=%23Bellator281', 'promoted_content': None, 'query': '%23Bellator281', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.6524686
# neutral sentiment
# tweet_sentiment_score: 0.6525
# positive 0.7321195
# positive sentiment
# tweet_sentiment_score: 1.4642000198364258
# neutral 0.8777336
# neutral sentiment
# tweet_sentiment_score: 0.8777
# neutral 0.7284971
# neutral sentiment
# tweet_sentiment_score: 0.7285
# total_sentiment_score: 3.7228999733924866
# {'_id': ObjectId('627ecb207ea96d6a094d4ca7'), 'name': 'Iran', 'url': 'http://twitter.com/search?q=Iran', 'promoted_content': None, 'query': 'Iran', 'tweet_volume': 75969, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.52680415
# neutral sentiment
# tweet_sentiment_score: 0.5268
# negative 0.72144866
# negative sentiment
# tweet_sentiment_score: -0.7214
# neutral 0.60486126
# neutral sentiment
# tweet_sentiment_score: 0.6049
# neutral 0.6639441
# neutral sentiment
# tweet_sentiment_score: 0.6639
# total_sentiment_score: 1.0741999745368958
# {'_id': ObjectId('627ecb207ea96d6a094d4cb7'), 'name': 'Nick Drake', 'url': 'http://twitter.com/search?q=%22Nick+Drake%22', 'promoted_content': None, 'query': '%22Nick+Drake%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# {'_id': ObjectId('627ecb207ea96d6a094d4c92'), 'name': '#LittleMixLastShow', 'url': 'http://twitter.com/search?q=%23LittleMixLastShow', 'promoted_content': None, 'query': '%23LittleMixLastShow', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# positive 0.9899519
# positive sentiment
# tweet_sentiment_score: 1.9800000190734863
# positive 0.98744524
# positive sentiment
# tweet_sentiment_score: 1.9747999906539917
# neutral 0.6892182
# neutral sentiment
# tweet_sentiment_score: 0.6892
# positive 0.9599847
# positive sentiment
# tweet_sentiment_score: 1.9199999570846558
# total_sentiment_score: 6.563999950885773
# {'_id': ObjectId('627ecb207ea96d6a094d4ca1'), 'name': 'Cameron Jerome', 'url': 'http://twitter.com/search?q=%22Cameron+Jerome%22', 'promoted_content': None, 'query': '%22Cameron+Jerome%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.8344859
# neutral sentiment
# tweet_sentiment_score: 0.8345
# total_sentiment_score: 0.8345000147819519
# {'_id': ObjectId('627ecb207ea96d6a094d4ca9'), 'name': 'Niko', 'url': 'http://twitter.com/search?q=Niko', 'promoted_content': None, 'query': 'Niko', 'tweet_volume': 26413, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.48674163
# neutral sentiment
# tweet_sentiment_score: 0.4867
# neutral 0.8144369
# neutral sentiment
# tweet_sentiment_score: 0.8144
# neutral 0.9333647
# neutral sentiment
# tweet_sentiment_score: 0.9334
# neutral 0.95364285
# neutral sentiment
# tweet_sentiment_score: 0.9536
# total_sentiment_score: 3.188099980354309
# {'_id': ObjectId('627ecb207ea96d6a094d4caa'), 'name': "She's 96", 'url': 'http://twitter.com/search?q=%22She%27s+96%22', 'promoted_content': None, 'query': '%22She%27s+96%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# negative 0.7296214
# negative sentiment
# tweet_sentiment_score: -0.7296
# neutral 0.54208606
# neutral sentiment
# tweet_sentiment_score: 0.5421
# positive 0.7245566
# positive sentiment
# tweet_sentiment_score: 1.4492000341415405
# negative 0.6006865
# negative sentiment
# tweet_sentiment_score: -0.6007
# total_sentiment_score: 0.6610000133514404
# {'_id': ObjectId('627ecb207ea96d6a094d4cad'), 'name': 'David McGoldrick', 'url': 'http://twitter.com/search?q=%22David+McGoldrick%22', 'promoted_content': None, 'query': '%22David+McGoldrick%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# positive 0.8335851
# positive sentiment
# tweet_sentiment_score: 1.667199969291687
# neutral 0.8460703
# neutral sentiment
# tweet_sentiment_score: 0.8461
# total_sentiment_score: 2.5132999420166016
# {'_id': ObjectId('627ecb207ea96d6a094d4cb9'), 'name': 'Scottish Cup Final', 'url': 'http://twitter.com/search?q=%22Scottish+Cup+Final%22', 'promoted_content': None, 'query': '%22Scottish+Cup+Final%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.74000776
# neutral sentiment
# tweet_sentiment_score: 0.74
# positive 0.62864465
# positive sentiment
# tweet_sentiment_score: 1.257200002670288
# neutral 0.8742696
# neutral sentiment
# tweet_sentiment_score: 0.8743
# neutral 0.7893272
# neutral sentiment
# tweet_sentiment_score: 0.7893
# total_sentiment_score: 3.660800039768219
# {'_id': ObjectId('627ecb207ea96d6a094d4cbb'), 'name': 'Zionist', 'url': 'http://twitter.com/search?q=Zionist', 'promoted_content': None, 'query': 'Zionist', 'tweet_volume': 20518, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# negative 0.66648656
# negative sentiment
# tweet_sentiment_score: -0.6665
# negative 0.7877809
# negative sentiment
# tweet_sentiment_score: -0.7878
# negative 0.7662851
# negative sentiment
# tweet_sentiment_score: -0.7663
# neutral 0.53164005
# neutral sentiment
# tweet_sentiment_score: 0.5316
# total_sentiment_score: -1.6890000104904175
# {'_id': ObjectId('627ecb207ea96d6a094d4c97'), 'name': '#totp', 'url': 'http://twitter.com/search?q=%23totp', 'promoted_content': None, 'query': '%23totp', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.90625536
# neutral sentiment
# tweet_sentiment_score: 0.9063
# total_sentiment_score: 0.9063000082969666
# {'_id': ObjectId('627ecb207ea96d6a094d4c9c'), 'name': 'Michael Stewart', 'url': 'http://twitter.com/search?q=%22Michael+Stewart%22', 'promoted_content': None, 'query': '%22Michael+Stewart%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# {'_id': ObjectId('627ecb207ea96d6a094d4c9d'), 'name': 'Israel', 'url': 'http://twitter.com/search?q=Israel', 'promoted_content': None, 'query': 'Israel', 'tweet_volume': 406453, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# negative 0.5620319
# negative sentiment
# tweet_sentiment_score: -0.562
# negative 0.72459966
# negative sentiment
# tweet_sentiment_score: -0.7246
# negative 0.5567882
# negative sentiment
# tweet_sentiment_score: -0.5568
# neutral 0.59925187
# neutral sentiment
# tweet_sentiment_score: 0.5993
# total_sentiment_score: -1.2440999746322632
# {'_id': ObjectId('627ecb207ea96d6a094d4c9e'), 'name': 'Didzy', 'url': 'http://twitter.com/search?q=Didzy', 'promoted_content': None, 'query': 'Didzy', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.8065458
# neutral sentiment
# tweet_sentiment_score: 0.8065
# positive 0.9723103
# positive sentiment
# tweet_sentiment_score: 1.944599986076355
# positive 0.98647827
# positive sentiment
# tweet_sentiment_score: 1.9730000495910645
# positive 0.976194
# positive sentiment
# tweet_sentiment_score: 1.9523999691009521
# total_sentiment_score: 6.676500022411346
# {'_id': ObjectId('627ecb207ea96d6a094d4c8e'), 'name': 'Stradivarius', 'url': 'http://twitter.com/search?q=Stradivarius', 'promoted_content': None, 'query': 'Stradivarius', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# positive 0.99218863
# positive sentiment
# tweet_sentiment_score: 1.9844000339508057
# positive 0.65630156
# positive sentiment
# tweet_sentiment_score: 1.312600016593933
# neutral 0.6388475
# neutral sentiment
# tweet_sentiment_score: 0.6388
# positive 0.9453818
# positive sentiment
# tweet_sentiment_score: 1.8907999992370605
# total_sentiment_score: 5.826600074768066
# {'_id': ObjectId('627ecb207ea96d6a094d4c93'), 'name': '#EverythingEverywhereAllAtOnce', 'url': 'http://twitter.com/search?q=%23EverythingEverywhereAllAtOnce', 'promoted_content': None, 'query': '%23EverythingEverywhereAllAtOnce', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# positive 0.8925438
# positive sentiment
# tweet_sentiment_score: 1.784999966621399
# neutral 0.4814547
# neutral sentiment
# tweet_sentiment_score: 0.4815
# positive 0.93006
# positive sentiment
# tweet_sentiment_score: 1.860200047492981
# neutral 0.62653023
# neutral sentiment
# tweet_sentiment_score: 0.6265
# total_sentiment_score: 4.753200024366379
# {'_id': ObjectId('627ecb207ea96d6a094d4cb4'), 'name': 'Whitney', 'url': 'http://twitter.com/search?q=Whitney', 'promoted_content': None, 'query': 'Whitney', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.6549753
# neutral sentiment
# tweet_sentiment_score: 0.655
# neutral 0.7918337
# neutral sentiment
# tweet_sentiment_score: 0.7918
# neutral 0.6165489
# neutral sentiment
# tweet_sentiment_score: 0.6165
# positive 0.8910931
# positive sentiment
# tweet_sentiment_score: 1.7821999788284302
# total_sentiment_score: 3.8454999923706055
# {'_id': ObjectId('627ecb207ea96d6a094d4cb8'), 'name': 'Jostled', 'url': 'http://twitter.com/search?q=Jostled', 'promoted_content': None, 'query': 'Jostled', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# negative 0.8543116
# negative sentiment
# tweet_sentiment_score: -0.8543
# neutral 0.7776961
# neutral sentiment
# tweet_sentiment_score: 0.7777
# negative 0.8960234
# negative sentiment
# tweet_sentiment_score: -0.896
# negative 0.94982034
# negative sentiment
# tweet_sentiment_score: -0.9498
# total_sentiment_score: -1.9224000573158264
# {'_id': ObjectId('627ecb207ea96d6a094d4ca4'), 'name': 'Tremors', 'url': 'http://twitter.com/search?q=Tremors', 'promoted_content': None, 'query': 'Tremors', 'tweet_volume': 18003, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.61581594
# neutral sentiment
# tweet_sentiment_score: 0.6158
# positive 0.60849386
# positive sentiment
# tweet_sentiment_score: 1.2170000076293945
# neutral 0.6111991
# neutral sentiment
# tweet_sentiment_score: 0.6112
# neutral 0.6620743
# neutral sentiment
# tweet_sentiment_score: 0.6621
# total_sentiment_score: 3.106100022792816
# {'_id': ObjectId('627ecb207ea96d6a094d4ca8'), 'name': 'Edinburgh City', 'url': 'http://twitter.com/search?q=%22Edinburgh+City%22', 'promoted_content': None, 'query': '%22Edinburgh+City%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# positive 0.93717176
# positive sentiment
# tweet_sentiment_score: 1.874400019645691
# positive 0.6726746
# positive sentiment
# tweet_sentiment_score: 1.3453999757766724
# neutral 0.7794829
# neutral sentiment
# tweet_sentiment_score: 0.7795
# positive 0.95181835
# positive sentiment
# tweet_sentiment_score: 1.9035999774932861
# total_sentiment_score: 5.902899980545044
# {'_id': ObjectId('627ecb207ea96d6a094d4cac'), 'name': 'Sinani', 'url': 'http://twitter.com/search?q=Sinani', 'promoted_content': None, 'query': 'Sinani', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.8902189
# neutral sentiment
# tweet_sentiment_score: 0.8902
# neutral 0.9092248
# neutral sentiment
# tweet_sentiment_score: 0.9092
# total_sentiment_score: 1.7994000315666199
# {'_id': ObjectId('627ecb207ea96d6a094d4cb6'), 'name': 'David Bowie', 'url': 'http://twitter.com/search?q=%22David+Bowie%22', 'promoted_content': None, 'query': '%22David+Bowie%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.69568896
# neutral sentiment
# tweet_sentiment_score: 0.6957
# neutral 0.81267023
# neutral sentiment
# tweet_sentiment_score: 0.8127
# positive 0.7952
# positive sentiment
# tweet_sentiment_score: 1.590399980545044
# neutral 0.598048
# neutral sentiment
# tweet_sentiment_score: 0.598
# total_sentiment_score: 3.69679993391037
# {'_id': ObjectId('627ecb207ea96d6a094d4cae'), 'name': 'Palestine', 'url': 'http://twitter.com/search?q=Palestine', 'promoted_content': None, 'query': 'Palestine', 'tweet_volume': 102655, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.8617048
# neutral sentiment
# tweet_sentiment_score: 0.8617
# neutral 0.73757386
# neutral sentiment
# tweet_sentiment_score: 0.7376
# neutral 0.7009212
# neutral sentiment
# tweet_sentiment_score: 0.7009
# negative 0.7118184
# negative sentiment
# tweet_sentiment_score: -0.7118
# total_sentiment_score: 1.5884000658988953
# {'_id': ObjectId('627ecb207ea96d6a094d4caf'), 'name': 'Friday the 13th', 'url': 'http://twitter.com/search?q=%22Friday+the+13th%22', 'promoted_content': None, 'query': '%22Friday+the+13th%22', 'tweet_volume': 258955, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# neutral 0.673974
# neutral sentiment
# tweet_sentiment_score: 0.674
# neutral 0.4991557
# neutral sentiment
# tweet_sentiment_score: 0.4992
# neutral 0.65738386
# neutral sentiment
# tweet_sentiment_score: 0.6574
# neutral 0.90725106
# neutral sentiment
# tweet_sentiment_score: 0.9073
# total_sentiment_score: 2.7379000186920166
# {'_id': ObjectId('627ecb207ea96d6a094d4cb5'), 'name': 'Annan', 'url': 'http://twitter.com/search?q=Annan', 'promoted_content': None, 'query': 'Annan', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 13, 21, 18, 24), 'woeid': 44418}
# positive 0.73330665
# positive sentiment
# tweet_sentiment_score: 1.466599941253662
# neutral 0.76551265
# neutral sentiment
# tweet_sentiment_score: 0.7655
# positive 0.806479
# positive sentiment
# tweet_sentiment_score: 1.6130000352859497
# neutral 0.6816884
# neutral sentiment
# tweet_sentiment_score: 0.6817
# total_sentiment_score: 4.526799976825714
# {'_id': ObjectId('62814efaf122b2401c1b36cd'), 'name': 'Fabianski', 'url': 'http://twitter.com/search?q=Fabianski', 'promoted_content': None, 'query': 'Fabianski', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.76900655
# neutral sentiment
# tweet_sentiment_score: 0.769
# positive 0.862367
# positive sentiment
# tweet_sentiment_score: 1.7247999906539917
# neutral 0.6837995
# neutral sentiment
# tweet_sentiment_score: 0.6838
# positive 0.75038093
# positive sentiment
# tweet_sentiment_score: 1.5008000135421753
# total_sentiment_score: 4.678399980068207
# {'_id': ObjectId('62814efaf122b2401c1b36ce'), 'name': 'Toffees', 'url': 'http://twitter.com/search?q=Toffees', 'promoted_content': None, 'query': 'Toffees', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.88970304
# positive sentiment
# tweet_sentiment_score: 1.7793999910354614
# neutral 0.8889813
# neutral sentiment
# tweet_sentiment_score: 0.889
# neutral 0.57004505
# neutral sentiment
# tweet_sentiment_score: 0.57
# negative 0.6045505
# negative sentiment
# tweet_sentiment_score: -0.6046
# total_sentiment_score: 2.633799970149994
# {'_id': ObjectId('62814efaf122b2401c1b36cf'), 'name': '#MN16', 'url': 'http://twitter.com/search?q=%23MN16', 'promoted_content': None, 'query': '%23MN16', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.9610207
# positive sentiment
# tweet_sentiment_score: 1.9220000505447388
# positive 0.8923962
# positive sentiment
# tweet_sentiment_score: 1.7848000526428223
# neutral 0.5396604
# neutral sentiment
# tweet_sentiment_score: 0.5397
# positive 0.97509474
# positive sentiment
# tweet_sentiment_score: 1.9501999616622925
# total_sentiment_score: 6.196700036525726
# {'_id': ObjectId('62814efaf122b2401c1b36d0'), 'name': '#LEEBHA', 'url': 'http://twitter.com/search?q=%23LEEBHA', 'promoted_content': None, 'query': '%23LEEBHA', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.6810477
# positive sentiment
# tweet_sentiment_score: 1.3619999885559082
# neutral 0.73170644
# neutral sentiment
# tweet_sentiment_score: 0.7317
# neutral 0.88255423
# neutral sentiment
# tweet_sentiment_score: 0.8826
# neutral 0.6827668
# neutral sentiment
# tweet_sentiment_score: 0.6828
# total_sentiment_score: 3.6590999960899353
# {'_id': ObjectId('62814efaf122b2401c1b36d1'), 'name': 'Anthony Gordon', 'url': 'http://twitter.com/search?q=%22Anthony+Gordon%22', 'promoted_content': None, 'query': '%22Anthony+Gordon%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.6273365
# positive sentiment
# tweet_sentiment_score: 1.2546000480651855
# neutral 0.8492433
# neutral sentiment
# tweet_sentiment_score: 0.8492
# neutral 0.8570296
# neutral sentiment
# tweet_sentiment_score: 0.857
# neutral 0.92165864
# neutral sentiment
# tweet_sentiment_score: 0.9217
# total_sentiment_score: 3.8825000524520874
# {'_id': ObjectId('62814efaf122b2401c1b36d2'), 'name': '#WHUFC', 'url': 'http://twitter.com/search?q=%23WHUFC', 'promoted_content': None, 'query': '%23WHUFC', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.7412113
# positive sentiment
# tweet_sentiment_score: 1.4823999404907227
# positive 0.8615698
# positive sentiment
# tweet_sentiment_score: 1.7231999635696411
# positive 0.9042524
# positive sentiment
# tweet_sentiment_score: 1.8085999488830566
# positive 0.58646166
# positive sentiment
# tweet_sentiment_score: 1.1729999780654907
# total_sentiment_score: 6.187199831008911
# {'_id': ObjectId('62814efaf122b2401c1b36d3'), 'name': 'Coufal', 'url': 'http://twitter.com/search?q=Coufal', 'promoted_content': None, 'query': 'Coufal', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.89667714
# neutral sentiment
# tweet_sentiment_score: 0.8967
# neutral 0.69278544
# neutral sentiment
# tweet_sentiment_score: 0.6928
# negative 0.7424621
# negative sentiment
# tweet_sentiment_score: -0.7425
# neutral 0.8907119
# neutral sentiment
# tweet_sentiment_score: 0.8907
# total_sentiment_score: 1.7376999855041504
# {'_id': ObjectId('62814efaf122b2401c1b36d4'), 'name': 'Mavs', 'url': 'http://twitter.com/search?q=Mavs', 'promoted_content': None, 'query': 'Mavs', 'tweet_volume': 21160, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.76988894
# positive sentiment
# tweet_sentiment_score: 1.5398000478744507
# neutral 0.83779913
# neutral sentiment
# tweet_sentiment_score: 0.8378
# positive 0.9384876
# positive sentiment
# tweet_sentiment_score: 1.8769999742507935
# neutral 0.7264267
# neutral sentiment
# tweet_sentiment_score: 0.7264
# total_sentiment_score: 4.981000065803528
# {'_id': ObjectId('62814efaf122b2401c1b36d5'), 'name': 'Rodrigo', 'url': 'http://twitter.com/search?q=Rodrigo', 'promoted_content': None, 'query': 'Rodrigo', 'tweet_volume': 55507, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.9020591
# neutral sentiment
# tweet_sentiment_score: 0.9021
# neutral 0.8314461
# neutral sentiment
# tweet_sentiment_score: 0.8314
# neutral 0.5751022
# neutral sentiment
# tweet_sentiment_score: 0.5751
# neutral 0.8653483
# neutral sentiment
# tweet_sentiment_score: 0.8653
# total_sentiment_score: 3.173900008201599
# {'_id': ObjectId('62814efaf122b2401c1b36d6'), 'name': 'Wilf', 'url': 'http://twitter.com/search?q=Wilf', 'promoted_content': None, 'query': 'Wilf', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.98828274
# positive sentiment
# tweet_sentiment_score: 1.9766000509262085
# negative 0.65086824
# negative sentiment
# tweet_sentiment_score: -0.6509
# positive 0.96283585
# positive sentiment
# tweet_sentiment_score: 1.9256000518798828
# total_sentiment_score: 3.251300096511841
# {'_id': ObjectId('62814efaf122b2401c1b36d7'), 'name': 'Erin Cuthbert', 'url': 'http://twitter.com/search?q=%22Erin+Cuthbert%22', 'promoted_content': None, 'query': '%22Erin+Cuthbert%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.60429555
# positive sentiment
# tweet_sentiment_score: 1.2086000442504883
# positive 0.6971766
# positive sentiment
# tweet_sentiment_score: 1.3944000005722046
# neutral 0.48726743
# neutral sentiment
# tweet_sentiment_score: 0.4873
# positive 0.6541348
# positive sentiment
# tweet_sentiment_score: 1.3082000017166138
# total_sentiment_score: 4.398500055074692
# {'_id': ObjectId('62814efaf122b2401c1b36d8'), 'name': 'Edgeley Park', 'url': 'http://twitter.com/search?q=%22Edgeley+Park%22', 'promoted_content': None, 'query': '%22Edgeley+Park%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.73204124
# neutral sentiment
# tweet_sentiment_score: 0.732
# positive 0.90244025
# positive sentiment
# tweet_sentiment_score: 1.804800033569336
# positive 0.6165648
# positive sentiment
# tweet_sentiment_score: 1.233199954032898
# positive 0.8089397
# positive sentiment
# tweet_sentiment_score: 1.617799997329712
# total_sentiment_score: 5.387799978256226
# {'_id': ObjectId('62814efaf122b2401c1b36d9'), 'name': 'Fernandinho', 'url': 'http://twitter.com/search?q=Fernandinho', 'promoted_content': None, 'query': 'Fernandinho', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.9020591
# neutral sentiment
# tweet_sentiment_score: 0.9021
# neutral 0.9097736
# neutral sentiment
# tweet_sentiment_score: 0.9098
# neutral 0.7863327
# neutral sentiment
# tweet_sentiment_score: 0.7863
# neutral 0.89500886
# neutral sentiment
# tweet_sentiment_score: 0.895
# total_sentiment_score: 3.4932000041007996
# {'_id': ObjectId('62814efaf122b2401c1b36da'), 'name': '#sundayvibes', 'url': 'http://twitter.com/search?q=%23sundayvibes', 'promoted_content': None, 'query': '%23sundayvibes', 'tweet_volume': 32807, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.92263013
# neutral sentiment
# tweet_sentiment_score: 0.9226
# neutral 0.803938
# neutral sentiment
# tweet_sentiment_score: 0.8039
# neutral 0.77785826
# neutral sentiment
# tweet_sentiment_score: 0.7779
# positive 0.731143
# positive sentiment
# tweet_sentiment_score: 1.4622000455856323
# total_sentiment_score: 3.966600000858307
# {'_id': ObjectId('62814efaf122b2401c1b36db'), 'name': 'Zinchenko', 'url': 'http://twitter.com/search?q=Zinchenko', 'promoted_content': None, 'query': 'Zinchenko', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.9020591
# neutral sentiment
# tweet_sentiment_score: 0.9021
# neutral 0.88908726
# neutral sentiment
# tweet_sentiment_score: 0.8891
# neutral 0.7663973
# neutral sentiment
# tweet_sentiment_score: 0.7664
# neutral 0.82761914
# neutral sentiment
# tweet_sentiment_score: 0.8276
# total_sentiment_score: 3.385200023651123
# {'_id': ObjectId('62814efaf122b2401c1b36dc'), 'name': 'Pascal', 'url': 'http://twitter.com/search?q=Pascal', 'promoted_content': None, 'query': 'Pascal', 'tweet_volume': 12210, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.90173006
# neutral sentiment
# tweet_sentiment_score: 0.9017
# positive 0.6810477
# positive sentiment
# tweet_sentiment_score: 1.3619999885559082
# positive 0.7746118
# positive sentiment
# tweet_sentiment_score: 1.5492000579833984
# neutral 0.73170644
# neutral sentiment
# tweet_sentiment_score: 0.7317
# total_sentiment_score: 4.544600069522858
# {'_id': ObjectId('62814efaf122b2401c1b36dd'), 'name': 'Manchester City', 'url': 'http://twitter.com/search?q=%22Manchester+City%22', 'promoted_content': None, 'query': '%22Manchester+City%22', 'tweet_volume': 51899, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.79587567
# neutral sentiment
# tweet_sentiment_score: 0.7959
# neutral 0.9245948
# neutral sentiment
# tweet_sentiment_score: 0.9246
# neutral 0.77185833
# neutral sentiment
# tweet_sentiment_score: 0.7719
# neutral 0.84367645
# neutral sentiment
# tweet_sentiment_score: 0.8437
# total_sentiment_score: 3.3360999822616577
# {'_id': ObjectId('62814efaf122b2401c1b36de'), 'name': 'Buffalo', 'url': 'http://twitter.com/search?q=Buffalo', 'promoted_content': None, 'query': 'Buffalo', 'tweet_volume': 1399845, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# negative 0.79779184
# negative sentiment
# tweet_sentiment_score: -0.7978
# negative 0.91923517
# negative sentiment
# tweet_sentiment_score: -0.9192
# negative 0.7528488
# negative sentiment
# tweet_sentiment_score: -0.7528
# negative 0.64917433
# negative sentiment
# tweet_sentiment_score: -0.6492
# total_sentiment_score: -3.119000017642975
# {'_id': ObjectId('62814efaf122b2401c1b36df'), 'name': 'Everton', 'url': 'http://twitter.com/search?q=Everton', 'promoted_content': None, 'query': 'Everton', 'tweet_volume': 67584, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.84164983
# neutral sentiment
# tweet_sentiment_score: 0.8416
# positive 0.7160827
# positive sentiment
# tweet_sentiment_score: 1.4321999549865723
# neutral 0.6662473
# neutral sentiment
# tweet_sentiment_score: 0.6662
# negative 0.6272935
# negative sentiment
# tweet_sentiment_score: -0.6273
# total_sentiment_score: 2.3126999139785767
# {'_id': ObjectId('62814efaf122b2401c1b36e0'), 'name': 'Donna', 'url': 'http://twitter.com/search?q=Donna', 'promoted_content': None, 'query': 'Donna', 'tweet_volume': 20731, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.8577264
# neutral sentiment
# tweet_sentiment_score: 0.8577
# neutral 0.9071573
# neutral sentiment
# tweet_sentiment_score: 0.9072
# positive 0.97117007
# positive sentiment
# tweet_sentiment_score: 1.9423999786376953
# negative 0.5227296
# negative sentiment
# tweet_sentiment_score: -0.5227
# total_sentiment_score: 3.1845999360084534
# {'_id': ObjectId('62814efaf122b2401c1b36e1'), 'name': 'Rondon', 'url': 'http://twitter.com/search?q=Rondon', 'promoted_content': None, 'query': 'Rondon', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.74820346
# neutral sentiment
# tweet_sentiment_score: 0.7482
# negative 0.97124594
# negative sentiment
# tweet_sentiment_score: -0.9712
# neutral 0.8717811
# neutral sentiment
# tweet_sentiment_score: 0.8718
# negative 0.5898925
# negative sentiment
# tweet_sentiment_score: -0.5899
# total_sentiment_score: 0.05889999866485596
# {'_id': ObjectId('62814efaf122b2401c1b36e2'), 'name': 'David Tennant', 'url': 'http://twitter.com/search?q=%22David+Tennant%22', 'promoted_content': None, 'query': '%22David+Tennant%22', 'tweet_volume': 12486, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.9349983
# positive sentiment
# tweet_sentiment_score: 1.8700000047683716
# positive 0.92856
# positive sentiment
# tweet_sentiment_score: 1.857200026512146
# positive 0.8247587
# positive sentiment
# tweet_sentiment_score: 1.6496000289916992
# neutral 0.6732109
# neutral sentiment
# tweet_sentiment_score: 0.6732
# total_sentiment_score: 6.050000071525574
# {'_id': ObjectId('62814efaf122b2401c1b36e3'), 'name': 'Richarlison', 'url': 'http://twitter.com/search?q=Richarlison', 'promoted_content': None, 'query': 'Richarlison', 'tweet_volume': 10238, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.8354213
# neutral sentiment
# tweet_sentiment_score: 0.8354
# neutral 0.85673773
# neutral sentiment
# tweet_sentiment_score: 0.8567
# neutral 0.75427437
# neutral sentiment
# tweet_sentiment_score: 0.7543
# neutral 0.8889813
# neutral sentiment
# tweet_sentiment_score: 0.889
# total_sentiment_score: 3.3353999853134155
# {'_id': ObjectId('62814efaf122b2401c1b36e4'), 'name': 'Theo Hernandez', 'url': 'http://twitter.com/search?q=%22Theo+Hernandez%22', 'promoted_content': None, 'query': '%22Theo+Hernandez%22', 'tweet_volume': 24484, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.56779426
# positive sentiment
# tweet_sentiment_score: 1.135599970817566
# positive 0.95230734
# positive sentiment
# tweet_sentiment_score: 1.9046000242233276
# neutral 0.86997
# neutral sentiment
# tweet_sentiment_score: 0.87
# neutral 0.6969155
# neutral sentiment
# tweet_sentiment_score: 0.6969
# total_sentiment_score: 4.607100009918213
# {'_id': ObjectId('62814efaf122b2401c1b36e5'), 'name': 'Palace', 'url': 'http://twitter.com/search?q=Palace', 'promoted_content': None, 'query': 'Palace', 'tweet_volume': 40971, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.69698626
# neutral sentiment
# tweet_sentiment_score: 0.697
# negative 0.53553057
# negative sentiment
# tweet_sentiment_score: -0.5355
# neutral 0.6175159
# neutral sentiment
# tweet_sentiment_score: 0.6175
# negative 0.59140694
# negative sentiment
# tweet_sentiment_score: -0.5914
# total_sentiment_score: 0.1876000165939331
# {'_id': ObjectId('62814efaf122b2401c1b36e6'), 'name': 'West Ham', 'url': 'http://twitter.com/search?q=%22West+Ham%22', 'promoted_content': None, 'query': '%22West+Ham%22', 'tweet_volume': 106406, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.8923962
# positive sentiment
# tweet_sentiment_score: 1.7848000526428223
# neutral 0.82794654
# neutral sentiment
# tweet_sentiment_score: 0.8279
# neutral 0.6456946
# neutral sentiment
# tweet_sentiment_score: 0.6457
# neutral 0.5435653
# neutral sentiment
# tweet_sentiment_score: 0.5436
# total_sentiment_score: 3.802000045776367
# {'_id': ObjectId('62814efaf122b2401c1b36e7'), 'name': 'Mahrez', 'url': 'http://twitter.com/search?q=Mahrez', 'promoted_content': None, 'query': 'Mahrez', 'tweet_volume': 39219, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.9020591
# neutral sentiment
# tweet_sentiment_score: 0.9021
# neutral 0.6563193
# neutral sentiment
# tweet_sentiment_score: 0.6563
# neutral 0.76900655
# neutral sentiment
# tweet_sentiment_score: 0.769
# neutral 0.6837995
# neutral sentiment
# tweet_sentiment_score: 0.6838
# total_sentiment_score: 3.0112000107765198
# {'_id': ObjectId('62814efaf122b2401c1b36e8'), 'name': 'Branthwaite', 'url': 'http://twitter.com/search?q=Branthwaite', 'promoted_content': None, 'query': 'Branthwaite', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# negative 0.49627528
# negative sentiment
# tweet_sentiment_score: -0.4963
# neutral 0.5125465
# neutral sentiment
# tweet_sentiment_score: 0.5125
# neutral 0.758659
# neutral sentiment
# tweet_sentiment_score: 0.7587
# neutral 0.5451315
# neutral sentiment
# tweet_sentiment_score: 0.5451
# total_sentiment_score: 1.3199999630451202
# {'_id': ObjectId('62814efaf122b2401c1b36e9'), 'name': 'Michael Oliver', 'url': 'http://twitter.com/search?q=%22Michael+Oliver%22', 'promoted_content': None, 'query': '%22Michael+Oliver%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.5503779
# neutral sentiment
# tweet_sentiment_score: 0.5504
# neutral 0.58547497
# neutral sentiment
# tweet_sentiment_score: 0.5855
# neutral 0.863885
# neutral sentiment
# tweet_sentiment_score: 0.8639
# negative 0.58119947
# negative sentiment
# tweet_sentiment_score: -0.5812
# total_sentiment_score: 1.4186000227928162
# {'_id': ObjectId('62814efaf122b2401c1b36ea'), 'name': 'Gomes', 'url': 'http://twitter.com/search?q=Gomes', 'promoted_content': None, 'query': 'Gomes', 'tweet_volume': 20164, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.90793693
# neutral sentiment
# tweet_sentiment_score: 0.9079
# neutral 0.8445243
# neutral sentiment
# tweet_sentiment_score: 0.8445
# neutral 0.87397397
# neutral sentiment
# tweet_sentiment_score: 0.874
# neutral 0.89684886
# neutral sentiment
# tweet_sentiment_score: 0.8968
# total_sentiment_score: 3.52319997549057
# {'_id': ObjectId('62814efaf122b2401c1b36eb'), 'name': 'Eriksen', 'url': 'http://twitter.com/search?q=Eriksen', 'promoted_content': None, 'query': 'Eriksen', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.71041614
# neutral sentiment
# tweet_sentiment_score: 0.7104
# neutral 0.8762589
# neutral sentiment
# tweet_sentiment_score: 0.8763
# neutral 0.81239194
# neutral sentiment
# tweet_sentiment_score: 0.8124
# neutral 0.9209114
# neutral sentiment
# tweet_sentiment_score: 0.9209
# total_sentiment_score: 3.319999933242798
# {'_id': ObjectId('62814efaf122b2401c1b36ec'), 'name': 'Burnley', 'url': 'http://twitter.com/search?q=Burnley', 'promoted_content': None, 'query': 'Burnley', 'tweet_volume': 46682, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# negative 0.8982386
# negative sentiment
# tweet_sentiment_score: -0.8982
# neutral 0.8317532
# neutral sentiment
# tweet_sentiment_score: 0.8318
# neutral 0.71245825
# neutral sentiment
# tweet_sentiment_score: 0.7125
# neutral 0.8106233
# neutral sentiment
# tweet_sentiment_score: 0.8106
# total_sentiment_score: 1.4566999673843384
# {'_id': ObjectId('62814efaf122b2401c1b36ed'), 'name': 'Angel Delight', 'url': 'http://twitter.com/search?q=%22Angel+Delight%22', 'promoted_content': None, 'query': '%22Angel+Delight%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.94600594
# positive sentiment
# tweet_sentiment_score: 1.8919999599456787
# total_sentiment_score: 1.8919999599456787
# {'_id': ObjectId('62814efaf122b2401c1b36ee'), 'name': 'Trifle', 'url': 'http://twitter.com/search?q=Trifle', 'promoted_content': None, 'query': 'Trifle', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.79703754
# neutral sentiment
# tweet_sentiment_score: 0.797
# positive 0.96893543
# positive sentiment
# tweet_sentiment_score: 1.9378000497817993
# positive 0.80144316
# positive sentiment
# tweet_sentiment_score: 1.6028000116348267
# positive 0.9572358
# positive sentiment
# tweet_sentiment_score: 1.9143999814987183
# total_sentiment_score: 6.252000033855438
# {'_id': ObjectId('62814efaf122b2401c1b36ef'), 'name': 'Doucoure', 'url': 'http://twitter.com/search?q=Doucoure', 'promoted_content': None, 'query': 'Doucoure', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.917101
# neutral sentiment
# tweet_sentiment_score: 0.9171
# neutral 0.7896625
# neutral sentiment
# tweet_sentiment_score: 0.7897
# neutral 0.91531557
# neutral sentiment
# tweet_sentiment_score: 0.9153
# neutral 0.8156851
# neutral sentiment
# tweet_sentiment_score: 0.8157
# total_sentiment_score: 3.4377999901771545
# {'_id': ObjectId('62814efaf122b2401c1b36f0'), 'name': 'Rico Henry', 'url': 'http://twitter.com/search?q=%22Rico+Henry%22', 'promoted_content': None, 'query': '%22Rico+Henry%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.6273365
# positive sentiment
# tweet_sentiment_score: 1.2546000480651855
# positive 0.93586737
# positive sentiment
# tweet_sentiment_score: 1.8717999458312988
# neutral 0.69826996
# neutral sentiment
# tweet_sentiment_score: 0.6983
# positive 0.57285917
# positive sentiment
# tweet_sentiment_score: 1.145799994468689
# total_sentiment_score: 4.9704999923706055
# {'_id': ObjectId('62814efaf122b2401c1b36f1'), 'name': 'Southampton', 'url': 'http://twitter.com/search?q=Southampton', 'promoted_content': None, 'query': 'Southampton', 'tweet_volume': 12961, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.89130133
# positive sentiment
# tweet_sentiment_score: 1.7826000452041626
# neutral 0.85334456
# neutral sentiment
# tweet_sentiment_score: 0.8533
# negative 0.6790899
# negative sentiment
# tweet_sentiment_score: -0.6791
# neutral 0.7400985
# neutral sentiment
# tweet_sentiment_score: 0.7401
# total_sentiment_score: 2.6969000697135925
# {'_id': ObjectId('62814efaf122b2401c1b36f2'), 'name': 'Stockport', 'url': 'http://twitter.com/search?q=Stockport', 'promoted_content': None, 'query': 'Stockport', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.67996633
# positive sentiment
# tweet_sentiment_score: 1.3600000143051147
# positive 0.9785079
# positive sentiment
# tweet_sentiment_score: 1.9570000171661377
# positive 0.970792
# positive sentiment
# tweet_sentiment_score: 1.94159996509552
# positive 0.87502927
# positive sentiment
# tweet_sentiment_score: 1.75
# total_sentiment_score: 7.0085999965667725
# {'_id': ObjectId('62814efaf122b2401c1b36f3'), 'name': 'Bowen', 'url': 'http://twitter.com/search?q=Bowen', 'promoted_content': None, 'query': 'Bowen', 'tweet_volume': 38016, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.5388582
# neutral sentiment
# tweet_sentiment_score: 0.5389
# neutral 0.8602014
# neutral sentiment
# tweet_sentiment_score: 0.8602
# neutral 0.80722517
# neutral sentiment
# tweet_sentiment_score: 0.8072
# neutral 0.6354198
# neutral sentiment
# tweet_sentiment_score: 0.6354
# total_sentiment_score: 2.84170001745224
# {'_id': ObjectId('62814efaf122b2401c1b36f4'), 'name': 'Arctic Roll', 'url': 'http://twitter.com/search?q=%22Arctic+Roll%22', 'promoted_content': None, 'query': '%22Arctic+Roll%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# {'_id': ObjectId('62814efaf122b2401c1b36f5'), 'name': 'Frank Lampard', 'url': 'http://twitter.com/search?q=%22Frank+Lampard%22', 'promoted_content': None, 'query': '%22Frank+Lampard%22', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.57004505
# neutral sentiment
# tweet_sentiment_score: 0.57
# neutral 0.57141584
# neutral sentiment
# tweet_sentiment_score: 0.5714
# neutral 0.8018746
# neutral sentiment
# tweet_sentiment_score: 0.8019
# positive 0.91623515
# positive sentiment
# tweet_sentiment_score: 1.8323999643325806
# total_sentiment_score: 3.7756999731063843
# {'_id': ObjectId('62814efaf122b2401c1b36f6'), 'name': 'Grantham', 'url': 'http://twitter.com/search?q=Grantham', 'promoted_content': None, 'query': 'Grantham', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# negative 0.64723694
# negative sentiment
# tweet_sentiment_score: -0.6472
# neutral 0.7793809
# neutral sentiment
# tweet_sentiment_score: 0.7794
# neutral 0.5457396
# neutral sentiment
# tweet_sentiment_score: 0.5457
# neutral 0.6271439
# neutral sentiment
# tweet_sentiment_score: 0.6271
# total_sentiment_score: 1.3050000071525574
# {'_id': ObjectId('62814efaf122b2401c1b36f7'), 'name': 'Joffy', 'url': 'http://twitter.com/search?q=Joffy', 'promoted_content': None, 'query': 'Joffy', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.87022936
# positive sentiment
# tweet_sentiment_score: 1.740399956703186
# positive 0.8018721
# positive sentiment
# tweet_sentiment_score: 1.6038000583648682
# total_sentiment_score: 3.344200015068054
# {'_id': ObjectId('62814efaf122b2401c1b36f8'), 'name': 'Gerrard', 'url': 'http://twitter.com/search?q=Gerrard', 'promoted_content': None, 'query': 'Gerrard', 'tweet_volume': 28803, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# positive 0.6879451
# positive sentiment
# tweet_sentiment_score: 1.3758000135421753
# neutral 0.6260745
# neutral sentiment
# tweet_sentiment_score: 0.6261
# positive 0.5647916
# positive sentiment
# tweet_sentiment_score: 1.1296000480651855
# neutral 0.5435653
# neutral sentiment
# tweet_sentiment_score: 0.5436
# total_sentiment_score: 3.675100088119507
# {'_id': ObjectId('62814efaf122b2401c1b36f9'), 'name': 'Goodison', 'url': 'http://twitter.com/search?q=Goodison', 'promoted_content': None, 'query': 'Goodison', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# negative 0.6272935
# negative sentiment
# tweet_sentiment_score: -0.6273
# neutral 0.49358296
# neutral sentiment
# tweet_sentiment_score: 0.4936
# neutral 0.8492433
# neutral sentiment
# tweet_sentiment_score: 0.8492
# positive 0.93586737
# positive sentiment
# tweet_sentiment_score: 1.8717999458312988
# total_sentiment_score: 2.587299942970276
# {'_id': ObjectId('62814efaf122b2401c1b36fa'), 'name': 'Allan', 'url': 'http://twitter.com/search?q=Allan', 'promoted_content': None, 'query': 'Allan', 'tweet_volume': 13320, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.83954936
# neutral sentiment
# tweet_sentiment_score: 0.8395
# negative 0.53838843
# negative sentiment
# tweet_sentiment_score: -0.5384
# neutral 0.8454646
# neutral sentiment
# tweet_sentiment_score: 0.8455
# neutral 0.5451315
# neutral sentiment
# tweet_sentiment_score: 0.5451
# total_sentiment_score: 1.6916999816894531
# {'_id': ObjectId('62814efaf122b2401c1b36fb'), 'name': 'Wrexham', 'url': 'http://twitter.com/search?q=Wrexham', 'promoted_content': None, 'query': 'Wrexham', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# negative 0.61904263
# negative sentiment
# tweet_sentiment_score: -0.619
# positive 0.9641224
# positive sentiment
# tweet_sentiment_score: 1.9282000064849854
# positive 0.9163136
# positive sentiment
# tweet_sentiment_score: 1.8325999975204468
# positive 0.72623837
# positive sentiment
# tweet_sentiment_score: 1.4523999691009521
# total_sentiment_score: 4.594199955463409
# {'_id': ObjectId('62814efaf122b2401c1b36fc'), 'name': 'Toney', 'url': 'http://twitter.com/search?q=Toney', 'promoted_content': None, 'query': 'Toney', 'tweet_volume': None, 'created_datetime': datetime.datetime(2022, 5, 15, 19, 5, 30), 'woeid': 44418}
# neutral 0.5125465
# neutral sentiment
# tweet_sentiment_score: 0.5125
# positive 0.5415965
# positive sentiment
# tweet_sentiment_score: 1.0831999778747559
# neutral 0.5845119
# neutral sentiment
# tweet_sentiment_score: 0.5845
# negative 0.5089398
# negative sentiment
# tweet_sentiment_score: -0.5089
# total_sentiment_score: 1.6712999939918518

# %% [markdown]
# ## *Date difference calculation*

# %%
# date difference calculation

# https://stackoverflow.com/a/151211/11005638
from datetime import date

mongo_datetime = twitter_trends[-1]['created_datetime']
print(mongo_datetime)

# d0 = date(2008, 8, 18)
d0 = mongo_datetime.date()
d1 = datetime.now().date()
# d1 = date(2008, 9, 26)

print('d0',d0)
print('d1',d1)

delta = d1 - d0
print(delta.days)
# Out:
# 2022-05-15 19:05:30
# d0 2022-05-15
# d1 2022-05-15
# 0

# %% [markdown]
# ## *datetime year correction for manually added dates*

# %%
for trend in twitter_trends:
  if trend['created_datetime'].year == 2021:
    print(trend)

    current_datetime = trend['created_datetime']

    # datetime(year, month, day, hour, minute, second, microsecond)
    # created_datetime = datetime(2022, 3, 13, 14, 0, 0, 0)
    updated_created_datetime = datetime(2022, current_datetime.month, current_datetime.day, current_datetime.hour, 0, 0, 0)

    # update in mongodb
    myquery = { "_id": trend["_id"] }
    newvalues = { "$set": { "created_datetime": updated_created_datetime } }

    trends_collection.update_one(myquery, newvalues)

# %% [markdown]
# ## Split Hashtags form Trends
#
# reference:
# * https://grantjenks.com/docs/wordsegment/
# * https://stackoverflow.com/a/32364566/11005638
# * https://grantjenks.com/docs/wordsegment/using-a-different-corpus.html
# * https://laurendahlin.github.io/colleges_on_social_media/Html/04_tweet_processing

# %% [markdown]
# ## Fetch Google Search top hits

# %% [markdown]
# ## Parse content using NLP
#
# - Extract details/ nouns from articles to understand categories that each trend falls into.
# *This will be used to create a relationship between trends (item-to-item like matching).*
# - Apply sentiment analysis

# %% [markdown]
# ## Analyze Sentiment
# sentiment of tweets (top 8) from the url

# %% [markdown]
# # Extra
#
# - Preprocess text: split hashtags, identify & translate language?
# - Fetch Reddit Trends
# - Fetch Google Trends
# - Parse Websites/ News sites
